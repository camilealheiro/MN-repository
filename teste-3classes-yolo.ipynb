# %% [markdown]
# # Notebook para testes feitos com predições para 3 classes [BN, BNMN, MN]
# Neste notebook estão os códigos utilizados para rodar os testes com diferentes configurações do YOLO (tanto para o YOLOv11, quanto para o YOLOv12) utilizando as 3 classes do dataset como as classes a serem treinadas e detectadas.

# %% [markdown]
# ### 1. Definição do caminho do diretório raíz do kaggle e instalação das bibliotecas necessárias

# %%
ROOT_DIR = '/kaggle/input/detectionbnmn-3classes'

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.158-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.158-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.6 MB/s eta 0:00:0000:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.158 ultralytics-thop-2.0.14

# %%
# !pip install opencv-python

# %% [markdown]
# ### 2. Importação de bibliotecas

# %%
import os
import numpy as np
import cv2
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ### 3. Treinamento YOLO

# %%
# mod = "/kaggle/input/yolo11/pytorch/default/1/yolo12s.pt"

#carregar o modelo
models = YOLO("yolo12l.pt") #cria um novo modelo

#Usar o modelo
results = models.train(data=os.path.join(ROOT_DIR, 'teste_file.yaml'), epochs=150, imgsz=1080, batch=2) #treinar o modelo

# %%
model_path = '/kaggle/working/runs/detect/train/weights/best.pt'
model = YOLO(model_path)

metrics = model.val()
metrics.box.map
metrics.box.map50
metrics.box.map75

# %% [markdown]
# ### 4. Funções de auxílio para a visualização dos resultados

# %%
from scipy.optimize import linear_sum_assignment

#Calcula o IOU dos resultados
def get_iou(ground_truth, pred):
    
    ix1 = np.maximum(ground_truth[0], pred[0])
    iy1 = np.maximum(ground_truth[1], pred[1])
    ix2 = np.minimum(ground_truth[2], pred[2])
    iy2 = np.minimum(ground_truth[3], pred[3])
     
    i_height = np.maximum(iy2 - iy1 + 1, np.array(0.))
    i_width = np.maximum(ix2 - ix1 + 1, np.array(0.))
     
    area_of_intersection = i_height * i_width
     
    gt_height = ground_truth[3] - ground_truth[1] + 1
    gt_width = ground_truth[2] - ground_truth[0] + 1
     
    pd_height = pred[3] - pred[1] + 1
    pd_width = pred[2] - pred[0] + 1
     
    area_of_union = gt_height * gt_width + pd_height * pd_width - area_of_intersection
     
    iou = area_of_intersection / area_of_union
     
    return iou

#Desenha as bboxes preditas
def draw_bounding_boxes(image, gt_box, pred_box, iou, threshold=0.5, class_correct=True, false_positive=True, pred_class_name=""):
    color = (0, 0, 255)
    label = ""

    if false_positive:
        color = (0, 0, 255)  # Vermelho
        label = "Detecção incorreta"
    elif class_correct and iou >= threshold:
        color = (0, 255, 0)  # Verde
        label = pred_class_name
    elif class_correct and iou == 0:
        color = (255, 0, 0)  # Azul
    elif class_correct and iou < threshold:
        color = (0, 255, 255)  # Amarelo
    elif class_correct is False:
        color = (0, 0, 255)  # Vermelho
        label = "Classe incorreta"

    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    thickness = 2
    (text_width, text_height), baseline = cv2.getTextSize(label, font, font_scale, thickness)

    if gt_box is not None:
        x1, y1, x2, y2 = map(int, gt_box)
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

        if label:
            y_text = y1 - 10 if y1 - 10 > 10 else y1 + text_height + 10
            cv2.rectangle(image,
                          (x1, y_text - text_height - baseline),
                          (x1 + text_width, y_text + baseline),
                          color, cv2.FILLED)
            cv2.putText(image, label, (x1, y_text), font, font_scale, (255, 255, 255), thickness)

    if gt_box is None and pred_box is not None:
        x1, y1, x2, y2 = map(int, pred_box)
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

        if label:
            y_text = y1 - 10 if y1 - 10 > 10 else y1 + text_height + 10
            cv2.rectangle(image,
                          (x1, y_text - text_height - baseline),
                          (x1 + text_width, y_text + baseline),
                          color, cv2.FILLED)
            cv2.putText(image, label, (x1, y_text), font, font_scale, (255, 255, 255), thickness)

    return image

#Carrega o ground truth para comparação
def load_ground_truth(label_path, image):
    boxes = []
    classes = []
    height, width, _ = image.shape
    with open(label_path, "r") as f:
        for line in f:
            class_id, center_x, center_y, bbox_width, bbox_height = map(float, line.strip().split())
            x1 = int((center_x - bbox_width / 2) * width)
            y1 = int((center_y - bbox_height / 2) * height)
            x2 = int((center_x + bbox_width / 2) * width)
            y2 = int((center_y + bbox_height / 2) * height)
            boxes.append([x1, y1, x2, y2])
            classes.append(int(class_id))
            
    return boxes, classes

#Faz a comparação do ground truth com as predições
def match_predictions_with_gt(gt_boxes, pred_boxes):
    num_gt = len(gt_boxes)
    num_pred = len(pred_boxes)
    
    iou_matrix = np.zeros((num_gt, num_pred))

    for i, gt in enumerate(gt_boxes):
        for j, pred in enumerate(pred_boxes):
            iou_matrix[i, j] = get_iou(gt, pred)
    
    # Resolver o problema de associação com Hungarian Algorithm
    gt_indices, pred_indices = linear_sum_assignment(-iou_matrix)  # Negativo porque queremos maximizar IoU
    
    # Identificar correspondências válidas
    matches = []
    unmatched_gt = set(range(num_gt))  # Ground truths sem correspondência
    unmatched_pred = set(range(num_pred))  # Predições sem correspondência

    for gt_idx, pred_idx in zip(gt_indices, pred_indices):
        iou = iou_matrix[gt_idx, pred_idx]
        if iou > 0:  # Apenas associações válidas
            matches.append((gt_idx, pred_idx, iou))
            unmatched_gt.discard(gt_idx)
            unmatched_pred.discard(pred_idx)

    # Adicionar GTs sem correspondência com IoU = 0
    for gt_idx in unmatched_gt:
        matches.append((gt_idx, None, 0.0))

    # Adicionar previsões sem correspondência como falsos positivos
    for pred_idx in unmatched_pred:
        matches.append((None, pred_idx, 0.0))

    return matches

# %%
image_dir = "/kaggle/input/detectionbnmn-3classes/images/test"
label_dir = "/kaggle/input/detectionbnmn-3classes/labels/test"
output_dir = "/kaggle/working/results_yolo11m"

model = YOLO("/kaggle/input/models/best_11m.pt")

image_paths = [os.path.join(image_dir, f) for f in os.listdir(image_dir)]
os.makedirs(output_dir, exist_ok=True)

class_names = ["BN", "BNMN", "MN"]

for img in image_paths:
    
    image = cv2.imread(img)
    image_name = os.path.basename(img)
    
    # Caminho do label correspondente
    label_path = os.path.join(label_dir, os.path.splitext(image_name)[0] + ".txt")
    
    # Carregar caixas Ground Truth
    if not os.path.exists(label_path):
        print(f"Label não encontrado para {image_name}. Pulando...")
        continue
    gt_boxes, gt_classes = load_ground_truth(label_path, image)
    
    # Fazer predições
    results = model.predict(img, save=False, show_conf=False, show_labels=False)
    pred_boxes = results[0].boxes.xyxy.cpu().numpy()
    pred_classes = results[0].boxes.cls.cpu().numpy().astype(int)

    matches = match_predictions_with_gt(gt_boxes, pred_boxes)

    for gt_idx, pred_idx, iou in matches:
        if gt_idx is not None:
            gt_box = gt_boxes[gt_idx]
            gt_class = gt_classes[gt_idx]
        else:
            gt_box, gt_class = None, None  # Não foi detectado
    
        if pred_idx is not None:
            pred_box = pred_boxes[pred_idx]
            pred_class = pred_classes[pred_idx]
        else:
            pred_box, pred_class = None, None  # Previsão sem correspondência
    
        # Desenhar caixas na imagem
        if gt_box is not None and pred_box is not None:
            class_correct = gt_class == pred_class
            # Caso normal: GT e predição correspondem
            if class_correct:
                print(f"imagem:{image_name}; iou: {iou}; classe correta")
            else:
                print(f"imagem: {image_name}; IoU: {iou:.2f}; classe incorreta (GT: {gt_class}, Pred: {pred_class}).")
                
            image = draw_bounding_boxes(image, gt_box, pred_box, iou, class_correct=class_correct, false_positive=False, pred_class_name=class_names[pred_class] if pred_class is not None else "")
                
        elif gt_box is not None:
            # Caso: GT sem correspondência (IoU = 0)
            print(f"imagem:{image_name}; objeto não detectado. IoU: 0")
            image = draw_bounding_boxes(image, gt_box, [0, 0, 0, 0], 0, false_positive=False, pred_class_name=class_names[pred_class] if pred_class is not None else "")
        
        elif pred_box is not None:
            # Caso: Previsão sem correspondência
            print(f"imagem:{image_name}; falso positivo detectado. IoU: 0")
            image = draw_bounding_boxes(image, [0, 0, 0, 0], pred_box, 0, false_positive=False, pred_class_name=class_names[pred_class] if pred_class is not None else "")
    save_path = os.path.join(output_dir, image_name)
    cv2.imwrite(save_path, image)
# Out:
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN172.png: 832x1088 1 BNMN, 2 MNs, 47.5ms
# Speed: 14.6ms preprocess, 47.5ms inference, 263.0ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN172.png; iou: 0.9148962514277833; classe correta
# imagem:BNMN172.png; iou: 0.730622789852844; classe correta
# imagem:BNMN172.png; iou: 0.9107079109298977; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN379.png: 832x1088 1 BN, 30.7ms
# Speed: 6.2ms preprocess, 30.7ms inference, 1.8ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN379.png; iou: 0.9856069432724882; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN53.png: 832x1088 1 BN, 30.7ms
# Speed: 6.0ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN53.png; iou: 0.9669991630094559; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN561.png: 832x1088 2 BNs, 30.7ms
# Speed: 6.0ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN561.png; iou: 0.9328978655342887; classe correta
# imagem:BN561.png; iou: 0.9354014286833862; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN682.png: 832x1088 1 BN, 30.7ms
# Speed: 6.4ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN682.png; iou: 0.8963735288516379; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN584.png: 832x1088 1 BN, 30.6ms
# Speed: 6.0ms preprocess, 30.6ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN584.png; iou: 0.9592827023074972; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN301.png: 832x1088 1 BN, 30.7ms
# Speed: 6.0ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem: BNMN301.png; IoU: 0.94; classe incorreta (GT: 1, Pred: 0).
# imagem:BNMN301.png; objeto não detectado. IoU: 0
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN260.png: 832x1088 1 BN, 1 BNMN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN260.png; iou: 0.9338779532696314; classe correta
# imagem:BNMN260.png; objeto não detectado. IoU: 0
# imagem:BNMN260.png; falso positivo detectado. IoU: 0
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN147.png: 832x1088 1 BNMN, 3 MNs, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN147.png; iou: 0.8837865837602046; classe correta
# imagem:BNMN147.png; iou: 0.9118021529421367; classe correta
# imagem:BNMN147.png; iou: 0.6466544315364894; classe correta
# imagem:BNMN147.png; falso positivo detectado. IoU: 0
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN557.png: 832x1088 1 BN, 30.6ms
# Speed: 6.6ms preprocess, 30.6ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN557.png; iou: 0.9489431266047138; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNM
png: 832x1088 1 BNMN, 1 MN, 30.7ms
# Speed: 6.2ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN359.png; iou: 0.6326627311321882; classe correta
# imagem:BNMN359.png; iou: 0.9271202841772598; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN337.png: 832x1088 1 BN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN337.png; iou: 0.8589583734513458; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN723.png: 832x1088 1 BN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN723.png; iou: 0.872345222277879; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN196.png: 832x1088 1 BNMN, 2 MNs, 30.7ms
# Speed: 6.0ms preprocess, 30.7ms inference, 2.1ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN196.png; iou: 0.7788686065820483; classe correta
# imagem:BNMN196.png; iou: 0.8241832568705866; classe correta
# imagem:BNMN196.png; iou: 0.8953965015779699; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN623.png: 832x1088 1 BN, 30.7ms
# Speed: 6.0ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN623.png; iou: 0.8968804752462348; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN330.png: 832x1088 1 BN, 30.7ms
# Speed: 6.4ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN330.png; iou: 0.9297299998246202; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN377.png: 832x1088 1 BN, 30.8ms
# Speed: 6.0ms preprocess, 30.8ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN377.png; iou: 0.9404971890870999; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN384.png: 832x1088 1 BN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN384.png; iou: 0.9525097733933924; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN116.png: 832x1088 1 BN, 30.7ms
# Speed: 5.9ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN116.png; iou: 0.9299627989436767; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN311.png: 832x1088 1 BN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN311.png; iou: 0.9481792304709153; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN305.png: 832x1088 1 BN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN305.png; iou: 0.9111016163752901; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN611.png: 832x1088 1 BN, 30.7ms
# Speed: 6.2ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN611.png; iou: 0.9527801768166405; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN254.png: 832x1088 1 BNMN, 1 MN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 2.3ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN254.png; iou: 0.7102381042078824; classe correta
# imagem:BNMN254.png; iou: 0.9451543916526104; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN174.png: 832x1088 1 BNMN, 1 MN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BNMN174.png; iou: 0.7486319309380816; classe correta
# imagem:BNMN174.png; iou: 0.9699013972222617; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN560.png: 832x1088 1 BN, 30.7ms
# Speed: 6.0ms preprocess, 30.7ms inference, 1.7ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN560.png; iou: 0.9604380151368728; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN559.png: 832x1088 1 BN, 30.7ms
# Speed: 6.2ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN559.png; iou: 0.9353723046228384; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN725.png: 832x1088 1 BN, 30.7ms
# Speed: 6.2ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN725.png; iou: 0.9233976275896544; classe correta
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BNMN197.png: 832x1088 1 BN, 30.7ms
# Speed: 6.1ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem: BNMN197.png; IoU: 0.94; classe incorreta (GT: 1, Pred: 0).
# imagem:BNMN197.png; objeto não detectado. IoU: 0
#
# image 1/1 /kaggle/input/detectionbnmn-3classes/images/test/BN625.png: 832x1088 1 BN, 30.7ms
# Speed: 5.9ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1088)
# imagem:BN625.png; iou: 0.9058579917044244; classe correta

# %% [markdown]
# ### 5. Compactação dos resultados das predições das imagens para download

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))


download_file('/kaggle/working/results_yolo11m', 'results_yolo11m')
# Out:
# /kaggle/working/results_yolo11m.zip

# %% [markdown]
# ### 6. Salva o resultado das predições em um CSV

# %%
from ultralytics import YOLO
import os

model = YOLO("/kaggle/input/models/yolo11s_3classes1080.pt")
source_dir = "/kaggle/input/detectionbnmn-3classes/images/test"
csv_path = "/kaggle/working/predicoes_11s.csv"

results = model.predict(source=source_dir)

with open(csv_path, "w", newline="") as f:
    import csv
    writer = csv.writer(f)
    writer.writerow(["file", "class_id", "class_name", "confidence", "x1", "y1", "x2", "y2"])

    for r in results:
        for box, conf, cls in zip(r.boxes.xyxy, r.boxes.conf, r.boxes.cls):
            x1, y1, x2, y2 = map(float, box.tolist())
            class_id = int(cls.item())
            class_name = r.names[class_id]
            writer.writerow([os.path.basename(r.path), class_id, class_name, float(conf.item()), x1, y1, x2, y2])

print(f"CSV salvo em {csv_path}")
# Out:
# image 1/268 /kaggle/input/detectionbnmn-3classes/images/test/BN112.png: 832x1088 1 BN, 13.8ms
# image 2/268 /kaggle/input/detectionbnmn-3classes/images/test/BN113.png: 832x1088 1 BN, 13.2ms
# image 3/268 /kaggle/input/detectionbnmn-3classes/images/test/BN115.png: 832x1088 1 BN, 13.1ms
# image 4/268 /kaggle/input/detectionbnmn-3classes/images/test/BN116.png: 832x1088 1 BN, 13.1ms
# image 5/268 /kaggle/input/detectionbnmn-3classes/images/test/BN117.png: 832x1088 2 BNs, 13.1ms
# image 6/268 /kaggle/input/detectionbnmn-3classes/images/test/BN136.png: 832x1088 1 BN, 13.2ms
# image 7/268 /kaggle/input/detectionbnmn-3classes/images/test/BN137.png: 832x1088 1 BN, 13.1ms
# image 8/268 /kaggle/input/detectionbnmn-3classes/images/test/BN143.png: 832x1088 1 BN, 13.1ms
# image 9/268 /kaggle/input/detectionbnmn-3classes/images/test/BN145.png: 832x1088 1 BN, 13.1ms
# image 10/268 /kaggle/input/detectionbnmn-3classes/images/test/BN152.png: 832x1088 1 BN, 13.1ms
# image 11/268 /kaggle/input/detectionbnmn-3classes/images/test/BN200.png: 832x1088 1 BN, 13.1ms
# image 12/268 /kaggle/input/detectionbnmn-3classes/images/test/BN201.png: 832x1088 1 BN, 13.1ms
# image 13/268 /kaggle/input/detectionbnmn-3classes/images/test/BN202.png: 832x1088 1 BN, 13.1ms
# image 14/268 /kaggle/input/detectionbnmn-3classes/images/test/BN205.png: 832x1088 1 BN, 13.1ms
# image 15/268 /kaggle/input/detectionbnmn-3classes/images/test/BN207.png: 832x1088 1 BN, 13.2ms
# image 16/268 /kaggle/input/detectionbnmn-3classes/images/test/BN226.png: 832x1088 2 BNs, 13.1ms
# image 17/268 /kaggle/input/detectionbnmn-3classes/images/test/BN227.png: 832x1088 2 BNs, 13.1ms
# image 18/268 /kaggle/input/detectionbnmn-3classes/images/test/BN229.png: 832x1088 1 BN, 13.1ms
# image 19/268 /kaggle/input/detectionbnmn-3classes/images/test/BN232.png: 832x1088 1 BN, 13.1ms
# image 20/268 /kaggle/input/detectionbnmn-3classes/images/test/BN261.png: 832x1088 1 BN, 13.1ms
# image 21/268 /kaggle/input/detectionbnmn-3classes/images/test/BN265.png: 832x1088 1 BN, 15.1ms
# image 22/268 /kaggle/input/detectionbnmn-3classes/images/test/BN269.png: 832x1088 1 BN, 13.1ms
# image 23/268 /kaggle/input/detectionbnmn-3classes/images/test/BN270.png: 832x1088 1 BN, 13.1ms
# image 24/268 /kaggle/input/detectionbnmn-3classes/images/test/BN272.png: 832x1088 1 BN, 13.1ms
# image 25/268 /kaggle/input/detectionbnmn-3classes/images/test/BN274.png: 832x1088 1 BN, 13.1ms
# image 26/268 /kaggle/input/detectionbnmn-3classes/images/test/BN275.png: 832x1088 2 BNs, 13.1ms
# image 27/268 /kaggle/input/detectionbnmn-3classes/images/test/BN276.png: 832x1088 1 BN, 13.1ms
# image 28/268 /kaggle/input/detectionbnmn-3classes/images/test/BN302.png: 832x1088 1 BN, 13.1ms
# image 29/268 /kaggle/input/detectionbnmn-3classes/images/test/BN303.png: 832x1088 1 BN, 13.1ms
# image 30/268 /kaggle/input/detectionbnmn-3classes/images/test/BN304.png: 832x1088 1 BN, 13.1ms
# image 31/268 /kaggle/input/detectionbnmn-3classes/images/test/BN305.png: 832x1088 1 BN, 13.1ms
# image 32/268 /kaggle/input/detectionbnmn-3classes/images/test/BN306.png: 832x1088 1 BN, 13.1ms
# image 33/268 /kaggle/input/detectionbnmn-3classes/images/test/BN307.png: 832x1088 1 BN, 13.1ms
# image 34/268 /kaggle/input/detectionbnmn-3classes/images/test/BN311.png: 832x1088 1 BN, 13.1ms
# image 35/268 /kaggle/input/detectionbnmn-3classes/images/test/BN329.png: 832x1088 1 BN, 13.1ms
# image 36/268 /kaggle/input/detectionbnmn-3classes/images/test/BN330.png: 832x1088 1 BN, 13.1ms
# image 37/268 /kaggle/input/detectionbnmn-3classes/images/test/BN331.png: 832x1088 2 BNs, 13.1ms
# image 38/268 /kaggle/input/detectionbnmn-3classes/images/test/BN332.png: 832x1088 2 BNs, 13.1ms
# image 39/268 /kaggle/input/detectionbnmn-3classes/images/test/BN333.png: 832x1088 1 BN, 13.1ms
# image 40/268 /kaggle/input/detectionbnmn-3classes/images/test/BN337.png: 832x1088 1 BN, 13.1ms
# image 41/268 /kaggle/input/detectionbnmn-3classes/images/test/BN343.png: 832x1088 1 BN, 13.1ms
# image 42/268 /kaggle/input/detectionbnmn-3classes/images/test/BN346.png: 832x1088 1 BN, 13.1ms
# image 43/268 /kaggle/input/detectionbnmn-3classes/images/test/BN347.png: 832x1088 1 BN, 13.1ms
# image 44/268 /kaggle/input/detectionbnmn-3classes/images/test/BN349.png: 832x1088 1 BN, 13.1ms
# image 45/268 /kaggle/input/detectionbnmn-3classes/images/test/BN351.png: 832x1088 1 BN, 13.1ms
# image 46/268 /kaggle/input/detectionbnmn-3classes/images/test/BN352.png: 832x1088 1 BN, 13.1ms
# image 47/268 /kaggle/input/detectionbnmn-3classes/images/test/BN353.png: 832x1088 1 BN, 13.2ms
# image 48/268 /kaggle/input/detectionbnmn-3classes/images/test/BN373.png: 832x1088 1 BN, 1 BNMN, 13.1ms
# image 49/268 /kaggle/input/detectionbnmn-3classes/images/test/BN374.png: 832x1088 1 BN, 13.1ms
# image 50/268 /kaggle/input/detectionbnmn-3classes/images/test/BN375.png: 832x1088 1 BN, 13.1ms
# image 51/268 /kaggle/input/detectionbnmn-3classes/images/test/BN376.png: 832x1088 1 BN, 13.1ms
# image 52/268 /kaggle/input/detectionbnmn-3classes/images/test/BN377.png: 832x1088 1 BN, 13.1ms
# image 53/268 /kaggle/input/detectionbnmn-3classes/images/test/BN378.png: 832x1088 1 BN, 13.1ms
# image 54/268 /kaggle/input/detectionbnmn-3classes/images/test/BN379.png: 832x1088 1 BN, 13.1ms
# image 55/268 /kaggle/input/detectionbnmn-3classes/images/test/BN380.png: 832x1088 1 BN, 13.1ms
# image 56/268 /kaggle/input/detectionbnmn-3classes/images/test/BN381.png: 832x1088 1 BN, 13.1ms
# image 57/268 /kaggle/input/detectionbnmn-3classes/images/test/BN382.png: 832x1088 1 BN, 13.1ms
# image 58/268 /kaggle/input/detectionbnmn-3classes/images/test/BN383.png: 832x1088 1 BN, 17.2ms
# image 59/268 /kaggle/input/detectionbnmn-3classes/images/test/BN384.png: 832x1088 1 BN, 13.1ms
# image 60/268 /kaggle/input/detectionbnmn-3classes/images/test/BN385.png: 832x1088 1 BN, 13.1ms
# image 61/268 /kaggle/input/detectionbnmn-3classes/images/test/BN389.png: 832x1088 1 BN, 13.1ms
# image 62/268 /kaggle/input/detectionbnmn-3classes/images/test/BN413.png: 832x1088 1 BN, 13.2ms
# image 63/268 /kaggle/input/detectionbnmn-3classes/images/test/BN414.png: 832x1088 1 BN, 13.1ms
# image 64/268 /kaggle/input/detectionbnmn-3classes/images/test/BN415.png: 832x1088 1 BN, 13.2ms
# image 65/268 /kaggle/input/detectionbnmn-3classes/images/test/BN416.png: 832x1088 1 BN, 13.2ms
# image 66/268 /kaggle/input/detectionbnmn-3classes/images/test/BN417.png: 832x1088 1 BN, 13.2ms
# image 67/268 /kaggle/input/detectionbnmn-3classes/images/test/BN418.png: 832x1088 1 BN, 13.2ms
# image 68/268 /kaggle/input/detectionbnmn-3classes/images/test/BN419.png: 832x1088 1 BN, 13.2ms
# image 69/268 /kaggle/input/detectionbnmn-3classes/images/test/BN420.png: 832x1088 1 BN, 13.1ms
# image 70/268 /kaggle/input/detectionbnmn-3classes/images/test/BN439.png: 832x1088 1 BN, 13.2ms
# image 71/268 /kaggle/input/detectionbnmn-3classes/images/test/BN440.png: 832x1088 1 BN, 13.2ms
# image 72/268 /kaggle/input/detectionbnmn-3classes/images/test/BN441.png: 832x1088 1 BN, 13.2ms
# image 73/268 /kaggle/input/detectionbnmn-3classes/images/test/BN442.png: 832x1088 1 BN, 13.1ms
# image 74/268 /kaggle/input/detectionbnmn-3classes/images/test/BN443.png: 832x1088 1 BN, 13.1ms
# image 75/268 /kaggle/input/detectionbnmn-3classes/images/test/BN444.png: 832x1088 1 BN, 13.1ms
# image 76/268 /kaggle/input/detectionbnmn-3classes/images/test/BN446.png: 832x1088 1 BN, 13.1ms
# image 77/268 /kaggle/input/detectionbnmn-3classes/images/test/BN447.png: 832x1088 1 BN, 13.2ms
# image 78/268 /kaggle/input/detectionbnmn-3classes/images/test/BN448.png: 832x1088 1 BN, 13.1ms
# image 79/268 /kaggle/input/detectionbnmn-3classes/images/test/BN468.png: 832x1088 1 BN, 13.1ms
# image 80/268 /kaggle/input/detectionbnmn-3classes/images/test/BN469.png: 832x1088 1 BN, 13.1ms
# image 81/268 /kaggle/input/detectionbnmn-3classes/images/test/BN470.png: 832x1088 1 BN, 13.1ms
# image 82/268 /kaggle/input/detectionbnmn-3classes/images/test/BN472.png: 832x1088 1 BN, 1 BNMN, 1 MN, 13.1ms
# image 83/268 /kaggle/input/detectionbnmn-3classes/images/test/BN473.png: 832x1088 1 BN, 13.1ms
# image 84/268 /kaggle/input/detectionbnmn-3classes/images/test/BN474.png: 832x1088 1 BN, 13.1ms
# image 85/268 /kaggle/input/detectionbnmn-3classes/images/test/BN475.png: 832x1088 1 BN, 13.1ms
# image 86/268 /kaggle/input/detectionbnmn-3classes/images/test/BN476.png: 832x1088 1 BN, 13.2ms
# image 87/268 /kaggle/input/detectionbnmn-3classes/images/test/BN477.png: 832x1088 1 BN, 13.1ms
# image 88/268 /kaggle/input/detectionbnmn-3classes/images/test/BN500.png: 832x1088 1 BN, 13.1ms
# image 89/268 /kaggle/input/detectionbnmn-3classes/images/test/BN501.png: 832x1088 1 BN, 13.1ms
# image 90/268 /kaggle/input/detectionbnmn-3classes/images/test/BN502.png: 832x1088 1 BN, 13.1ms
# image 91/268 /kaggle/input/detectionbnmn-3classes/images/test/BN504.png: 832x1088 1 BN, 13.1ms
# image 92/268 /kaggle/input/detectionbnmn-3classes/images/test/BN506.png: 832x1088 1 BN, 13.1ms
# image 93/268 /kaggle/input/detectionbnmn-3classes/images/test/BN507.png: 832x1088 1 BN, 13.1ms
# image 94/268 /kaggle/input/detectionbnmn-3classes/images/test/BN508.png: 832x1088 1 BN, 13.1ms
# image 95/268 /kaggle/input/detectionbnmn-3classes/images/test/BN509.png: 832x1088 1 BN, 13.1ms
# image 96/268 /kaggle/input/detectionbnmn-3classes/images/test/BN53.png: 832x1088 1 BN, 13.2ms
# image 97/268 /kaggle/input/detectionbnmn-3classes/images/test/BN531.png: 832x1088 1 BN, 13.1ms
# image 98/268 /kaggle/input/detectionbnmn-3classes/images/test/BN532.png: 832x1088 1 BN, 13.1ms
# image 99/268 /kaggle/input/detectionbnmn-3classes/images/test/BN533.png: 832x1088 1 BN, 13.1ms
# image 100/268 /kaggle/input/detectionbnmn-3classes/images/test/BN534.png: 832x1088 4 BNs, 13.1ms
# image 101/268 /kaggle/input/detectionbnmn-3classes/images/test/BN535.png: 832x1088 1 BN, 13.1ms
# image 102/268 /kaggle/input/detectionbnmn-3classes/images/test/BN536.png: 832x1088 2 BNs, 13.1ms
# image 103/268 /kaggle/input/detectionbnmn-3classes/images/test/BN54.png: 832x1088 1 BN, 13.1ms
# image 104/268 /kaggle/input/detectionbnmn-3classes/images/test/BN554.png: 832x1088 1 BN, 13.1ms
# image 105/268 /kaggle/input/detectionbnmn-3classes/images/test/BN555.png: 832x1088 2 BNs, 13.1ms
# image 106/268 /kaggle/input/detectionbnmn-3classes/images/test/BN556.png: 832x1088 1 BN, 13.2ms
# image 107/268 /kaggle/input/detectionbnmn-3classes/images/test/BN557.png: 832x1088 1 BN, 13.1ms
# image 108/268 /kaggle/input/detectionbnmn-3classes/images/test/BN558.png: 832x1088 1 BN, 1 MN, 13.1ms
# image 109/268 /kaggle/input/detectionbnmn-3classes/images/test/BN559.png: 832x1088 1 BN, 13.1ms
# image 110/268 /kaggle/input/detectionbnmn-3classes/images/test/BN56.png: 832x1088 1 BN, 13.1ms
# image 111/268 /kaggle/input/detectionbnmn-3classes/images/test/BN560.png: 832x1088 2 BNs, 13.1ms
# image 112/268 /kaggle/input/detectionbnmn-3classes/images/test/BN561.png: 832x1088 2 BNs, 13.1ms
# image 113/268 /kaggle/input/detectionbnmn-3classes/images/test/BN562.png: 832x1088 1 BN, 13.1ms
# image 114/268 /kaggle/input/detectionbnmn-3classes/images/test/BN583.png: 832x1088 1 BN, 13.1ms
# image 115/268 /kaggle/input/detectionbnmn-3classes/images/test/BN584.png: 832x1088 1 BN, 13.1ms
# image 116/268 /kaggle/input/detectionbnmn-3classes/images/test/BN585.png: 832x1088 1 BN, 13.1ms
# image 117/268 /kaggle/input/detectionbnmn-3classes/images/test/BN586.png: 832x1088 1 BN, 13.1ms
# image 118/268 /kaggle/input/detectionbnmn-3classes/images/test/BN587.png: 832x1088 1 BN, 13.1ms
# image 119/268 /kaggle/input/detectionbnmn-3classes/images/test/BN588.png: 832x1088 2 BNs, 13.1ms
# image 120/268 /kaggle/input/detectionbnmn-3classes/images/test/BN589.png: 832x1088 1 BN, 13.1ms
# image 121/268 /kaggle/input/detectionbnmn-3classes/images/test/BN607.png: 832x1088 1 BN, 13.1ms
# image 122/268 /kaggle/input/detectionbnmn-3classes/images/test/BN608.png: 832x1088 2 BNs, 1 BNMN, 1 MN, 13.1ms
# image 123/268 /kaggle/input/detectionbnmn-3classes/images/test/BN610.png: 832x1088 2 BNs, 13.1ms
# image 124/268 /kaggle/input/detectionbnmn-3classes/images/test/BN611.png: 832x1088 1 BN, 13.1ms
# image 125/268 /kaggle/input/detectionbnmn-3classes/images/test/BN612.png: 832x1088 1 BN, 13.1ms
# image 126/268 /kaggle/input/detectionbnmn-3classes/images/test/BN613.png: 832x1088 1 BN, 13.2ms
# image 127/268 /kaggle/input/detectionbnmn-3classes/images/test/BN623.png: 832x1088 1 BN, 13.2ms
# image 128/268 /kaggle/input/detectionbnmn-3classes/images/test/BN624.png: 832x1088 1 BN, 13.2ms
# image 129/268 /kaggle/input/detectionbnmn-3classes/images/test/BN625.png: 832x1088 1 BN, 13.2ms
# image 130/268 /kaggle/input/detectionbnmn-3classes/images/test/BN626.png: 832x1088 1 BN, 13.1ms
# image 131/268 /kaggle/input/detectionbnmn-3classes/images/test/BN627.png: 832x1088 1 BN, 13.1ms
# image 132/268 /kaggle/input/detectionbnmn-3classes/images/test/BN628.png: 832x1088 1 BN, 13.1ms
# image 133/268 /kaggle/input/detectionbnmn-3classes/images/test/BN637.png: 832x1088 1 BN, 13.1ms
# image 134/268 /kaggle/input/detectionbnmn-3classes/images/test/BN638.png: 832x1088 1 BN, 13.1ms
# image 135/268 /kaggle/input/detectionbnmn-3classes/images/test/BN639.png: 832x1088 1 BN, 13.1ms
# image 136/268 /kaggle/input/detectionbnmn-3classes/images/test/BN640.png: 832x1088 2 BNs, 13.1ms
# image 137/268 /kaggle/input/detectionbnmn-3classes/images/test/BN651.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 138/268 /kaggle/input/detectionbnmn-3classes/images/test/BN652.png: 832x1088 1 BN, 13.1ms
# image 139/268 /kaggle/input/detectionbnmn-3classes/images/test/BN653.png: 832x1088 2 BNs, 13.1ms
# image 140/268 /kaggle/input/detectionbnmn-3classes/images/test/BN654.png: 832x1088 1 BN, 13.1ms
# image 141/268 /kaggle/input/detectionbnmn-3classes/images/test/BN666.png: 832x1088 1 BN, 13.1ms
# image 142/268 /kaggle/input/detectionbnmn-3classes/images/test/BN667.png: 832x1088 1 BN, 13.1ms
# image 143/268 /kaggle/input/detectionbnmn-3classes/images/test/BN668.png: 832x1088 1 BN, 13.2ms
# image 144/268 /kaggle/input/detectionbnmn-3classes/images/test/BN669.png: 832x1088 1 BN, 13.1ms
# image 145/268 /kaggle/input/detectionbnmn-3classes/images/test/BN681.png: 832x1088 1 BN, 13.2ms
# image 146/268 /kaggle/input/detectionbnmn-3classes/images/test/BN682.png: 832x1088 1 BN, 13.1ms
# image 147/268 /kaggle/input/detectionbnmn-3classes/images/test/BN683.png: 832x1088 1 BN, 13.1ms
# image 148/268 /kaggle/input/detectionbnmn-3classes/images/test/BN684.png: 832x1088 1 BN, 13.1ms
# image 149/268 /kaggle/input/detectionbnmn-3classes/images/test/BN695.png: 832x1088 1 BN, 13.1ms
# image 150/268 /kaggle/input/detectionbnmn-3classes/images/test/BN696.png: 832x1088 1 BN, 13.1ms
# image 151/268 /kaggle/input/detectionbnmn-3classes/images/test/BN697.png: 832x1088 1 BN, 13.1ms
# image 152/268 /kaggle/input/detectionbnmn-3classes/images/test/BN698.png: 832x1088 1 BN, 13.1ms
# image 153/268 /kaggle/input/detectionbnmn-3classes/images/test/BN70.png: 832x1088 1 BN, 13.1ms
# image 154/268 /kaggle/input/detectionbnmn-3classes/images/test/BN709.png: 832x1088 2 BNs, 1 BNMN, 1 MN, 13.2ms
# image 155/268 /kaggle/input/detectionbnmn-3classes/images/test/BN710.png: 832x1088 1 BN, 13.1ms
# image 156/268 /kaggle/input/detectionbnmn-3classes/images/test/BN711.png: 832x1088 1 BN, 13.1ms
# image 157/268 /kaggle/input/detectionbnmn-3classes/images/test/BN712.png: 832x1088 1 BN, 13.1ms
# image 158/268 /kaggle/input/detectionbnmn-3classes/images/test/BN722.png: 832x1088 1 BN, 13.1ms
# image 159/268 /kaggle/input/detectionbnmn-3classes/images/test/BN723.png: 832x1088 1 BN, 13.2ms
# image 160/268 /kaggle/input/detectionbnmn-3classes/images/test/BN724.png: 832x1088 1 BN, 13.2ms
# image 161/268 /kaggle/input/detectionbnmn-3classes/images/test/BN725.png: 832x1088 1 BN, 13.1ms
# image 162/268 /kaggle/input/detectionbnmn-3classes/images/test/BN75.png: 832x1088 1 BN, 13.1ms
# image 163/268 /kaggle/input/detectionbnmn-3classes/images/test/BN76.png: 832x1088 1 BN, 13.1ms
# image 164/268 /kaggle/input/detectionbnmn-3classes/images/test/BN77.png: 832x1088 1 BN, 13.1ms
# image 165/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN147.png: 832x1088 2 BNMNs, 3 MNs, 13.2ms
# image 166/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN148.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 167/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN149.png: 832x1088 1 BNMN, 4 MNs, 13.1ms
# image 168/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN150.png: 832x1088 1 BNMN, 3 MNs, 13.2ms
# image 169/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN151.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 170/268 /kaggle/input/detectionbnmn-3classes/images/test/BNM
268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN257.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 232/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN260.png: 832x1088 1 BN, 1 BNMN, 1 MN, 13.1ms
# image 233/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN268.png: 832x1088 1 BNMN, 1 MN, 13.2ms
# image 234/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN269.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 235/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN270.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 236/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN271.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 237/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN278.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 238/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN279.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 239/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN280.png: 832x1088 1 BN, 1 BNMN, 1 MN, 13.1ms
# image 240/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN281.png: 832x1088 3 BNs, 1 BNMN, 1 MN, 13.1ms
# image 241/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN293.png: 832x1088 2 BNs, 13.1ms
# image 242/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN294.png: 832x1088 1 BN, 1 BNMN, 1 MN, 13.1ms
# image 243/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN301.png: 832x1088 1 BN, 1 BNMN, 1 MN, 13.2ms
# image 244/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN302.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 245/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN309.png: 832x1088 1 BN, 1 BNMN, 2 MNs, 13.1ms
# image 246/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN310.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 247/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN317.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 248/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN318.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 249/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN325.png: 832x1088 1 BN, 13.1ms
# image 250/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN326.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 251/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN334.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 252/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN336.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 253/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN343.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 254/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN344.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 255/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN351.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 256/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN352.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 257/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN359.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 258/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN360.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 259/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN366.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 260/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN367.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 261/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN368.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 262/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN369.png: 832x1088 1 BNMN, 2 MNs, 13.2ms
# image 263/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN374.png: 832x1088 1 BNMN, 1 MN, 13.2ms
# image 264/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN375.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# image 265/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN376.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 266/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN377.png: 832x1088 2 BNMNs, 1 MN, 13.1ms
# image 267/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN382.png: 832x1088 1 BNMN, 1 MN, 13.1ms
# image 268/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN383.png: 832x1088 1 BNMN, 2 MNs, 13.1ms
# Speed: 5.8ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 832, 1088)
# CSV salvo em /kaggle/working/predicoes_11s.csv

# %% [markdown]
# ## Extra: Remoção das classes nas anotações para treinamento de 2 ou 1 classe
# O código abaixo teve a função de fazer a remoção nos labels originais (com 3 classes) das classes desejadas, para que futuramente fosse possível treinar os modelos com detecção apenas para 2 classes (BN e BNMN) ou 1 classe (MN), testes estes que foram realizados na intenção de estudar e aplicar a possibilidade da técnica de ensemble.

# %%
import os

# Caminho para o diretório com os arquivos de anotação originais
labels_orig = '/kaggle/input/detectionbnmn-3classes/labels/train'
labels_out = '/kaggle/working/train_2classe'

os.makedirs(labels_out, exist_ok=True)

for filename in os.listdir(labels_orig):
    if filename.endswith('.txt'):
        input_path = os.path.join(labels_orig, filename)
        output_path = os.path.join(labels_out, filename)

        # Ler o arquivo e filtrar as linhas
        with open(input_path, 'r') as file:
            lines = file.readlines()

        # Manter apenas as linhas que não têm o class_id que queremos remover
        new_lines = [line for line in lines if not line.startswith('2')]
        # new_lines = [line for line in lines if line.startswith('2')]

        # Escrever o novo arquivo no diretório de saída
        with open(output_path, 'w') as file:
            file.writelines(new_lines)

print("Anotações da classe MN removidas e salvas no novo diretório com sucesso.")
