# %% [markdown]
# # Notebook para a realização dos testes de ensemble
# Neste notebook está o código usado para a realização dos testes de mistura de modelos (ensemble) onde foram juntados duas detecções de modelos diferentes e aplicado um pós-processamento após isso, na tentativa de uma otimização de resultados

# %% [markdown]
# ### 1. Instalação das bibliotecas necessárias no kaggle

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.78-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.78-py3-none-any.whl (921 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.78 ultralytics-thop-2.0.14

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->opencv-python) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.2->opencv-python) (2024.2.0)

# %% [markdown]
# ### 2. Importação das bibliotecas

# %%
import os
import numpy as np
import cv2
from ultralytics import YOLO
from collections import defaultdict
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ### 3. Chamada e aplicação da predição dos modelos treinados (3 classes e 1 classe)

# %%
model_BN_path = "/kaggle/input/models/yolo11l_3classes1080.pt"
model_MN_path = "/kaggle/input/models/yolo11s_1classe1080.pt"

model_BN = YOLO(model_BN_path)
model_MN = YOLO(model_MN_path)

# %%
model_BN.predict(source="/kaggle/input/detectionbnmn-3classes/images/test", save=False, show_conf=False, show_labels=False, save_txt=True)
# Out:
# image 1/268 /kaggle/input/detectionbnmn-3classes/images/test/BN112.png: 832x1088 1 BN, 2628.6ms
# image 2/268 /kaggle/input/detectionbnmn-3classes/images/test/BN113.png: 832x1088 1 BN, 2472.9ms
# image 3/268 /kaggle/input/detectionbnmn-3classes/images/test/BN115.png: 832x1088 1 BN, 2399.7ms
# image 4/268 /kaggle/input/detectionbnmn-3classes/images/test/BN116.png: 832x1088 1 BN, 2449.9ms
# image 5/268 /kaggle/input/detectionbnmn-3classes/images/test/BN117.png: 832x1088 1 BN, 2441.5ms
# image 6/268 /kaggle/input/detectionbnmn-3classes/images/test/BN136.png: 832x1088 1 BN, 2418.3ms
# image 7/268 /kaggle/input/detectionbnmn-3classes/images/test/BN137.png: 832x1088 1 BN, 2339.4ms
# image 8/268 /kaggle/input/detectionbnmn-3classes/images/test/BN143.png: 832x1088 1 BN, 2441.8ms
# image 9/268 /kaggle/input/detectionbnmn-3classes/images/test/BN145.png: 832x1088 1 BN, 2441.0ms
# image 10/268 /kaggle/input/detectionbnmn-3classes/images/test/BN152.png: 832x1088 1 BN, 2647.8ms
# image 11/268 /kaggle/input/detectionbnmn-3classes/images/test/BN200.png: 832x1088 1 BN, 2459.0ms
# image 12/268 /kaggle/input/detectionbnmn-3classes/images/test/BN201.png: 832x1088 1 BN, 2411.1ms
# image 13/268 /kaggle/input/detectionbnmn-3classes/images/test/BN202.png: 832x1088 1 BN, 2447.2ms
# image 14/268 /kaggle/input/detectionbnmn-3classes/images/test/BN205.png: 832x1088 1 BN, 2460.3ms
# image 15/268 /kaggle/input/detectionbnmn-3classes/images/test/BN207.png: 832x1088 1 BN, 2487.0ms
# image 16/268 /kaggle/input/detectionbnmn-3classes/images/test/BN226.png: 832x1088 2 BNs, 2487.5ms
# image 17/268 /kaggle/input/detectionbnmn-3classes/images/test/BN227.png: 832x1088 2 BNs, 2381.9ms
# image 18/268 /kaggle/input/detectionbnmn-3classes/images/test/BN229.png: 832x1088 1 BN, 2520.0ms
# image 19/268 /kaggle/input/detectionbnmn-3classes/images/test/BN232.png: 832x1088 1 BN, 2453.7ms
# image 20/268 /kaggle/input/detectionbnmn-3classes/images/test/BN261.png: 832x1088 1 BN, 2466.2ms
# image 21/268 /kaggle/input/detectionbnmn-3classes/images/test/BN265.png: 832x1088 1 BN, 2409.4ms
# image 22/268 /kaggle/input/detectionbnmn-3classes/images/test/BN269.png: 832x1088 1 BN, 2528.2ms
# image 23/268 /kaggle/input/detectionbnmn-3classes/images/test/BN270.png: 832x1088 1 BN, 2491.0ms
# image 24/268 /kaggle/input/detectionbnmn-3classes/images/test/BN272.png: 832x1088 1 BN, 2474.5ms
# image 25/268 /kaggle/input/detectionbnmn-3classes/images/test/BN274.png: 832x1088 1 BN, 2471.5ms
# image 26/268 /kaggle/input/detectionbnmn-3classes/images/test/BN275.png: 832x1088 2 BNs, 2441.5ms
# image 27/268 /kaggle/input/detectionbnmn-3classes/images/test/BN276.png: 832x1088 1 BN, 2426.5ms
# image 28/268 /kaggle/input/detectionbnmn-3classes/images/test/BN302.png: 832x1088 1 BN, 2431.6ms
# image 29/268 /kaggle/input/detectionbnmn-3classes/images/test/BN303.png: 832x1088 1 BN, 2492.4ms
# image 30/268 /kaggle/input/detectionbnmn-3classes/images/test/BN304.png: 832x1088 1 BN, 2462.9ms
# image 31/268 /kaggle/input/detectionbnmn-3classes/images/test/BN305.png: 832x1088 1 BN, 2427.4ms
# image 32/268 /kaggle/input/detectionbnmn-3classes/images/test/BN306.png: 832x1088 1 BN, 2381.0ms
# image 33/268 /kaggle/input/detectionbnmn-3classes/images/test/BN307.png: 832x1088 1 BN, 2465.0ms
# image 34/268 /kaggle/input/detectionbnmn-3classes/images/test/BN311.png: 832x1088 1 BN, 2536.4ms
# image 35/268 /kaggle/input/detectionbnmn-3classes/images/test/BN329.png: 832x1088 1 BN, 2474.0ms
# image 36/268 /kaggle/input/detectionbnmn-3classes/images/test/BN330.png: 832x1088 1 BN, 2484.9ms
# image 37/268 /kaggle/input/detectionbnmn-3classes/images/test/BN331.png: 832x1088 1 BN, 2488.2ms
# image 38/268 /kaggle/input/detectionbnmn-3classes/images/test/BN332.png: 832x1088 2 BNs, 2528.6ms
# image 39/268 /kaggle/input/detectionbnmn-3classes/images/test/BN333.png: 832x1088 1 BN, 2438.3ms
# image 40/268 /kaggle/input/detectionbnmn-3classes/images/test/BN337.png: 832x1088 1 BN, 2485.0ms
# image 41/268 /kaggle/input/detectionbnmn-3classes/images/test/BN343.png: 832x1088 1 BN, 2445.3ms
# image 42/268 /kaggle/input/detectionbnmn-3classes/images/test/BN346.png: 832x1088 1 BN, 2482.5ms
# image 43/268 /kaggle/input/detectionbnmn-3classes/images/test/BN347.png: 832x1088 1 BN, 2456.7ms
# image 44/268 /kaggle/input/detectionbnmn-3classes/images/test/BN349.png: 832x1088 1 BN, 2463.1ms
# image 45/268 /kaggle/input/detectionbnmn-3classes/images/test/BN351.png: 832x1088 1 BN, 2472.0ms
# image 46/268 /kaggle/input/detectionbnmn-3classes/images/test/BN352.png: 832x1088 1 BN, 1 BNMN, 2535.2ms
# image 47/268 /kaggle/input/detectionbnmn-3classes/images/test/BN353.png: 832x1088 1 BN, 2533.0ms
# image 48/268 /kaggle/input/detectionbnmn-3classes/images/test/BN373.png: 832x1088 1 BN, 2546.1ms
# image 49/268 /kaggle/input/detectionbnmn-3classes/images/test/BN374.png: 832x1088 1 BN, 2459.9ms
# image 50/268 /kaggle/input/detectionbnmn-3classes/images/test/BN375.png: 832x1088 1 BN, 2464.9ms
# image 51/268 /kaggle/input/detectionbnmn-3classes/images/test/BN376.png: 832x1088 1 BN, 2453.5ms
# image 52/268 /kaggle/input/detectionbnmn-3classes/images/test/BN377.png: 832x1088 1 BN, 2444.7ms
# image 53/268 /kaggle/input/detectionbnmn-3classes/images/test/BN378.png: 832x1088 1 BN, 2501.0ms
# image 54/268 /kaggle/input/detectionbnmn-3classes/images/test/BN379.png: 832x1088 1 BN, 2465.6ms
# image 55/268 /kaggle/input/detectionbnmn-3classes/images/test/BN380.png: 832x1088 1 BN, 2364.9ms
# image 56/268 /kaggle/input/detectionbnmn-3classes/images/test/BN381.png: 832x1088 1 BN, 2499.8ms
# image 57/268 /kaggle/input/detectionbnmn-3classes/images/test/BN382.png: 832x1088 1 BN, 2481.4ms
# image 58/268 /kaggle/input/detectionbnmn-3classes/images/test/BN383.png: 832x1088 1 BN, 2549.9ms
# image 59/268 /kaggle/input/detectionbnmn-3classes/images/test/BN384.png: 832x1088 1 BN, 2535.9ms
# image 60/268 /kaggle/input/detectionbnmn-3classes/images/test/BN385.png: 832x1088 1 BN, 2466.4ms
# image 61/268 /kaggle/input/detectionbnmn-3classes/images/test/BN389.png: 832x1088 1 BN, 2422.4ms
# image 62/268 /kaggle/input/detectionbnmn-3classes/images/test/BN413.png: 832x1088 1 BN, 2444.7ms
# image 63/268 /kaggle/input/detectionbnmn-3classes/images/test/BN414.png: 832x1088 1 BN, 2450.8ms
# image 64/268 /kaggle/input/detectionbnmn-3classes/images/test/BN415.png: 832x1088 1 BN, 2483.7ms
# image 65/268 /kaggle/input/detectionbnmn-3classes/images/test/BN416.png: 832x1088 1 BN, 2427.4ms
# image 66/268 /kaggle/input/detectionbnmn-3classes/images/test/BN417.png: 832x1088 1 BN, 2506.9ms
# image 67/268 /kaggle/input/detectionbnmn-3classes/images/test/BN418.png: 832x1088 1 BN, 2410.8ms
# image 68/268 /kaggle/input/detectionbnmn-3classes/images/test/BN419.png: 832x1088 1 BNMN, 1 MN, 2491.4ms
# image 69/268 /kaggle/input/detectionbnmn-3classes/images/test/BN420.png: 832x1088 1 BN, 2434.5ms
# image 70/268 /kaggle/input/detectionbnmn-3classes/images/test/BN439.png: 832x1088 1 BN, 2529.8ms
# image 71/268 /kaggle/input/detectionbnmn-3classes/images/test/BN440.png: 832x1088 1 BN, 2566.3ms
# image 72/268 /kaggle/input/detectionbnmn-3classes/images/test/BN441.png: 832x1088 1 BN, 2495.2ms
# image 73/268 /kaggle/input/detectionbnmn-3classes/images/test/BN442.png: 832x1088 1 BN, 2450.7ms
# image 74/268 /kaggle/input/detectionbnmn-3classes/images/test/BN443.png: 832x1088 1 BN, 2422.4ms
# image 75/268 /kaggle/input/detectionbnmn-3classes/images/test/BN444.png: 832x1088 1 BN, 2443.8ms
# image 76/268 /kaggle/input/detectionbnmn-3classes/images/test/BN446.png: 832x1088 1 BN, 2466.2ms
# image 77/268 /kaggle/input/detectionbnmn-3classes/images/test/BN447.png: 832x1088 1 BN, 2538.6ms
# image 78/268 /kaggle/input/detectionbnmn-3classes/images/test/BN448.png: 832x1088 1 BN, 2473.8ms
# image 79/268 /kaggle/input/detectionbnmn-3classes/images/test/BN468.png: 832x1088 1 BN, 2498.9ms
# image 80/268 /kaggle/input/detectionbnmn-3classes/images/test/BN469.png: 832x1088 1 BN, 2472.9ms
# image 81/268 /kaggle/input/detectionbnmn-3classes/images/test/BN470.png: 832x1088 1 BN, 2471.0ms
# image 82/268 /kaggle/input/detectionbnmn-3classes/images/test/BN472.png: 832x1088 1 BN, 2595.3ms
# image 83/268 /kaggle/input/detectionbnmn-3classes/images/test/BN473.png: 832x1088 1 BN, 2476.9ms
# image 84/268 /kaggle/input/detectionbnmn-3classes/images/test/BN474.png: 832x1088 1 BN, 2384.8ms
# image 85/268 /kaggle/input/detectionbnmn-3classes/images/test/BN475.png: 832x1088 1 BN, 2481.9ms
# image 86/268 /kaggle/input/detectionbnmn-3classes/images/test/BN476.png: 832x1088 1 BN, 2497.0ms
# image 87/268 /kaggle/input/detectionbnmn-3classes/images/test/BN477.png: 832x1088 1 BN, 2421.0ms
# image 88/268 /kaggle/input/detectionbnmn-3classes/images/test/BN500.png: 832x1088 1 BN, 1 BNMN, 2535.5ms
# image 89/268 /kaggle/input/detectionbnmn-3classes/images/test/BN501.png: 832x1088 1 BN, 2409.4ms
# image 90/268 /kaggle/input/detectionbnmn-3classes/images/test/BN502.png: 832x1088 1 BN, 2475.4ms
# image 91/268 /kaggle/input/detectionbnmn-3classes/images/test/BN504.png: 832x1088 1 BN, 2441.6ms
# image 92/268 /kaggle/input/detectionbnmn-3classes/images/test/BN506.png: 832x1088 1 BN, 2471.4ms
# image 93/268 /kaggle/input/detectionbnmn-3classes/images/test/BN507.png: 832x1088 1 BN, 2465.2ms
# image 94/268 /kaggle/input/detectionbnmn-3classes/images/test/BN508.png: 832x1088 1 BN, 2529.0ms
# image 95/268 /kaggle/input/detectionbnmn-3classes/images/test/BN509.png: 832x1088 1 BN, 2490.2ms
# image 96/268 /kaggle/input/detectionbnmn-3classes/images/test/BN53.png: 832x1088 1 BN, 2496.0ms
# image 97/268 /kaggle/input/detectionbnmn-3classes/images/test/BN531.png: 832x1088 1 BN, 2523.7ms
# image 98/268 /kaggle/input/detectionbnmn-3classes/images/test/BN532.png: 832x1088 1 BN, 2414.9ms
# image 99/268 /kaggle/input/detectionbnmn-3classes/images/test/BN533.png: 832x1088 1 BN, 2452.7ms
# image 100/268 /kaggle/input/detectionbnmn-3classes/images/test/BN534.png: 832x1088 4 BNs, 2468.6ms
# image 101/268 /kaggle/input/detectionbnmn-3classes/images/test/BN535.png: 832x1088 1 BN, 2492.8ms
# image 102/268 /kaggle/input/detectionbnmn-3classes/images/test/BN536.png: 832x1088 2 BNs, 2513.5ms
# image 103/268 /kaggle/input/detectionbnmn-3classes/images/test/BN54.png: 832x1088 2 BNs, 2482.9ms
# image 104/268 /kaggle/input/detectionbnmn-3classes/images/test/BN554.png: 832x1088 1 BN, 2483.4ms
# image 105/268 /kaggle/input/detectionbnmn-3classes/images/test/BN555.png: 832x1088 2 BNs, 2472.1ms
# image 106/268 /kaggle/input/detectionbnmn-3classes/images/test/BN556.png: 832x1088 1 BN, 2550.9ms
# image 107/268 /kaggle/input/detectionbnmn-3classes/images/test/BN557.png: 832x1088 1 BN, 2502.6ms
# image 108/268 /kaggle/input/detectionbnmn-3classes/images/test/BN558.png: 832x1088 1 BN, 2480.7ms
# image 109/268 /kaggle/input/detectionbnmn-3classes/images/test/BN559.png: 832x1088 1 BN, 2481.7ms
# image 110/268 /kaggle/input/detectionbnmn-3classes/images/test/BN56.png: 832x1088 1 BN, 2510.0ms
# image 111/268 /kaggle/input/detectionbnmn-3classes/images/test/BN560.png: 832x1088 1 BN, 2483.9ms
# image 112/268 /kaggle/input/detectionbnmn-3classes/images/test/BN561.png: 832x1088 2 BNs, 2506.3ms
# image 113/268 /kaggle/input/detectionbnmn-3classes/images/test/BN562.png: 832x1088 1 BN, 2444.6ms
# image 114/268 /kaggle/input/detectionbnmn-3classes/images/test/BN583.png: 832x1088 1 BN, 2515.7ms
# image 115/268 /kaggle/input/detectionbnmn-3classes/images/test/BN584.png: 832x1088 1 BN, 2589.1ms
# image 116/268 /kaggle/input/detectionbnmn-3classes/images/test/BN585.png: 832x1088 1 BN, 2476.1ms
# image 117/268 /kaggle/input/detectionbnmn-3classes/images/test/BN586.png: 832x1088 1 BN, 2471.4ms
# image 118/268 /kaggle/input/detectionbnmn-3classes/images/test/BN587.png: 832x1088 1 BN, 2643.1ms
# image 119/268 /kaggle/input/detectionbnmn-3classes/images/test/BN588.png: 832x1088 2 BNs, 2480.2ms
# image 120/268 /kaggle/input/detectionbnmn-3classes/images/test/BN589.png: 832x1088 1 BN, 2437.9ms
# image 121/268 /kaggle/input/detectionbnmn-3classes/images/test/BN607.png: 832x1088 1 BN, 2434.6ms
# image 122/268 /kaggle/input/detectionbnmn-3classes/images/test/BN608.png: 832x1088 2 BNs, 1 MN, 2498.5ms
# image 123/268 /kaggle/input/detectionbnmn-3classes/images/test/BN610.png: 832x1088 2 BNs, 2538.5ms
# image 124/268 /kaggle/input/detectionbnmn-3classes/images/test/BN611.png: 832x1088 1 BN, 2458.1ms
# image 125/268 /kaggle/input/detectionbnmn-3classes/images/test/BN612.png: 832x1088 1 BN, 2491.4ms
# image 126/268 /kaggle/input/detectionbnmn-3classes/images/test/BN613.png: 832x1088 1 BN, 2511.6ms
# image 127/268 /kaggle/input/detectionbnmn-3classes/images/test/BN623.png: 832x1088 1 BN, 2500.0ms
# image 128/268 /kaggle/input/detectionbnmn-3classes/images/test/BN624.png: 832x1088 1 BN, 2476.8ms
# image 129/268 /kaggle/input/detectionbnmn-3classes/images/test/BN625.png: 832x1088 1 BN, 2534.0ms
# image 130/268 /kaggle/input/detectionbnmn-3classes/images/test/BN626.png: 832x1088 1 BN, 2538.6ms
# image 131/268 /kaggle/input/detectionbnmn-3classes/images/test/BN627.png: 832x1088 1 BN, 2492.7ms
# image 132/268 /kaggle/input/detectionbnmn-3classes/images/test/BN628.png: 832x1088 1 BN, 2437.5ms
# image 133/268 /kaggle/input/detectionbnmn-3classes/images/test/BN637.png: 832x1088 1 BN, 2452.2ms
# image 134/268 /kaggle/input/detectionbnmn-3classes/images/test/BN638.png: 832x1088 1 BN, 2457.8ms
# image 135/268 /kaggle/input/detectionbnmn-3classes/images/test/BN639.png: 832x1088 1 BN, 2401.2ms
# image 136/268 /kaggle/input/detectionbnmn-3classes/images/test/BN640.png: 832x1088 2 BNs, 2515.5ms
# image 137/268 /kaggle/input/detectionbnmn-3classes/images/test/BN651.png: 832x1088 1 BNMN, 2 MNs, 2438.1ms
# image 138/268 /kaggle/input/detectionbnmn-3classes/images/test/BN652.png: 832x1088 1 BN, 2492.2ms
# image 139/268 /kaggle/input/detectionbnmn-3classes/images/test/BN653.png: 832x1088 2 BNs, 2459.4ms
# image 140/268 /kaggle/input/detectionbnmn-3classes/images/test/BN654.png: 832x1088 1 BN, 2390.5ms
# image 141/268 /kaggle/input/detectionbnmn-3classes/images/test/BN666.png: 832x1088 1 BN, 2464.6ms
# image 142/268 /kaggle/input/detectionbnmn-3classes/images/test/BN667.png: 832x1088 1 BN, 2622.2ms
# image 143/268 /kaggle/input/detectionbnmn-3classes/images/test/BN668.png: 832x1088 1 BN, 2487.3ms
# image 144/268 /kaggle/input/detectionbnmn-3classes/images/test/BN669.png: 832x1088 1 BN, 2525.5ms
# image 145/268 /kaggle/input/detectionbnmn-3classes/images/test/BN681.png: 832x1088 1 BN, 2508.0ms
# image 146/268 /kaggle/input/detectionbnmn-3classes/images/test/BN682.png: 832x1088 1 BN, 2457.6ms
# image 147/268 /kaggle/input/detectionbnmn-3classes/images/test/BN683.png: 832x1088 1 BN, 2497.8ms
# image 148/268 /kaggle/input/detectionbnmn-3classes/images/test/BN684.png: 832x1088 1 BN, 2502.2ms
# image 149/268 /kaggle/input/detectionbnmn-3classes/images/test/BN695.png: 832x1088 1 BN, 2482.3ms
# image 150/268 /kaggle/input/detectionbnmn-3classes/images/test/BN696.png: 832x1088 1 BN, 2429.5ms
# image 151/268 /kaggle/input/detectionbnmn-3classes/images/test/BN697.png: 832x1088 1 BN, 2530.3ms
# image 152/268 /kaggle/input/detectionbnmn-3classes/images/test/BN698.png: 832x1088 1 BN, 2468.4ms
# image 153/268 /kaggle/input/detectionbnmn-3classes/images/test/BN70.png: 832x1088 1 BN, 2493.9ms
# image 154/268 /kaggle/input/detectionbnmn-3classes/images/test/BN709.png: 832x1088 1 BN, 1 BNMN, 1 MN, 2654.5ms
# image 155/268 /kaggle/input/detectionbnmn-3classes/images/test/BN710.png: 832x1088 1 BN, 2468.8ms
# image 156/268 /kaggle/input/detectionbnmn-3classes/images/test/BN711.png: 832x1088 1 BN, 2411.8ms
# image 157/268 /kaggle/input/detectionbnmn-3classes/images/test/BN712.png: 832x1088 1 BN, 2436.5ms
# image 158/268 /kaggle/input/detectionbnmn-3classes/images/test/BN722.png: 832x1088 1 BN, 2516.8ms
# image 159/268 /kaggle/input/detectionbnmn-3classes/images/test/BN723.png: 832x1088 1 BN, 2456.8ms
# image 160/268 /kaggle/input/detectionbnmn-3classes/images/test/BN724.png: 832x1088 1 BN, 2434.4ms
# image 161/268 /kaggle/input/detectionbnmn-3classes/images/test/BN725.png: 832x1088 1 BN, 2412.5ms
# image 162/268 /kaggle/input/detectionbnmn-3classes/images/test/BN75.png: 832x1088 1 BN, 2473.2ms
# image 163/268 /kaggle/input/detectionbnmn-3classes/images/test/BN76.png: 832x1088 1 BN, 2520.3ms
# image 164/268 /kaggle/input/detectionbnmn-3classes/images/test/BN77.png: 832x1088 1 BN, 2479.0ms
# image 165/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN147.png: 832x1088 1 BNMN, 2 MNs, 2445.7ms
# image 166/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN148.png: 832x1088 1 BNMN, 1 MN, 2605.0ms
# image 167/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN149.png: 832x1088 1 BNMN, 2 MNs, 2435.0ms
# image 168/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN150.png: 832x1088 1 BNMN, 2 MNs, 2422.5ms
# image 169/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN151.png: 832x1088 1 BNMN, 2 MNs, 2441.7ms
# image 170/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN152.png: 832x1088 1 BNMN, 2 MNs, 2423.7ms
# image 171/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN153.png: 832x1088 1 BNMN, 2 MNs, 2501.4ms
# image 172/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN154.png: 832x1088 1 BNMN, 1 MN, 2440.5ms
# image 173/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN155.png: 832x1088 1 BNMN, 1 MN, 2495.1ms
# image 174/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN156.png: 832x1088 1 BNMN, 1 MN, 2451.9ms
# image 175/268 /kaggle/input/detectionbnmn-3classes/images/test/BNM
268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN351.png: 832x1088 1 BNMN, 3 MNs, 2481.2ms
# image 256/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN352.png: 832x1088 1 BNMN, 1 MN, 2431.6ms
# image 257/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN359.png: 832x1088 1 BNMN, 1 MN, 2442.3ms
# image 258/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN360.png: 832x1088 1 BNMN, 1 MN, 2446.8ms
# image 259/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN366.png: 832x1088 1 BNMN, 1 MN, 2438.3ms
# image 260/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN367.png: 832x1088 1 BNMN, 1 MN, 2487.2ms
# image 261/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN368.png: 832x1088 1 BNMN, 1 MN, 2456.4ms
# image 262/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN369.png: 832x1088 1 BNMN, 2 MNs, 2662.0ms
# image 263/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN374.png: 832x1088 1 BNMN, 1 MN, 2462.3ms
# image 264/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN375.png: 832x1088 1 BNMN, 2 MNs, 2453.8ms
# image 265/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN376.png: 832x1088 1 BNMN, 1 MN, 2513.6ms
# image 266/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN377.png: 832x1088 2 BNMNs, 1 MN, 2489.6ms
# image 267/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN382.png: 832x1088 1 BNMN, 1 MN, 2462.9ms
# image 268/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN383.png: 832x1088 1 BNMN, 1 MN, 2468.0ms
# Speed: 10.3ms preprocess, 2478.1ms inference, 1.6ms postprocess per image at shape (1, 3, 832, 1088)
# Results saved to runs/detect/predict
# 268 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 44,  49, 126],
#          [ 47,  49, 123],
#          [ 47,  49, 125],
#          ...,
#          [ 60,  52, 144],
#          [ 68,  49, 145],
#          [ 63,  49, 147]],
#
#         [[ 45,  47, 126],
#          [ 49,  48, 123],
#          [ 49,  49, 125],
#          ...,
#          [ 58,  55, 143],
#          [ 67,  51, 144],
#          [ 64,  51, 144]],
#
#         [[ 44,  48, 124],
#          [ 48,  45, 124],
#          [ 51,  48, 124],
#          ...,
#          [ 59,  55, 142],
#          [ 63,  52, 142],
#          [ 62,  54, 143]],
#
#         ...,
#
#         [[ 51,  54, 129],
#          [ 52,  56, 127],
#          [ 52,  56, 129],
#          ...,
#          [ 64,  66, 159],
#          [ 63,  68, 157],
#          [ 66,  69, 155]],
#
#         [[ 51,  49, 132],
#          [ 51,  52, 129],
#          [ 49,  55, 129],
#          ...,
#          [ 67,  66, 157],
#          [ 71,  67, 153],
#          [ 68,  71, 150]],
#
#         [[ 51,  51, 131],
#          [ 51,  48, 133],
#          [ 48,  51, 132],
#          ...,
#          [ 68,  63, 159],
#          [ 74,  63, 156],
#          [ 68,  67, 155]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN112.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 19.46258544921875, 'inference': 2628.6282539367676, 'postprocess': 19.7145938873291},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 51,  47, 123],
#          [ 51,  45, 125],
#          [ 49,  47, 125],
#          ...,
#          [ 56,  58, 150],
#          [ 56,  58, 150],
#          [ 62,  56, 151]],
#
#         [[ 56,  45, 122],
#          [ 51,  47, 124],
#          [ 48,  48, 125],
#          ...,
#          [ 56,  59, 149],
#          [ 67,  55, 148],
#          [ 69,  54, 148]],
#
#         [[ 49,  48, 123],
#          [ 49,  49, 123],
#          [ 49,  49, 124],
#          ...,
#          [ 58,  58, 151],
#          [ 63,  55, 149],
#          [ 66,  56, 145]],
#
#         ...,
#
#         [[ 49,  32, 148],
#          [ 59,  34, 142],
#          [ 67,  30, 142],
#          ...,
#          [ 66,  63, 160],
#          [ 69,  63, 159],
#          [ 67,  63, 160]],
#
#         [[ 47,  30, 155],
#          [ 55,  32, 148],
#          [ 63,  29, 148],
#          ...,
#          [ 67,  62, 159],
#          [ 71,  63, 158],
#          [ 64,  66, 159]],
#
#         [[ 42,  34, 159],
#          [ 51,  32, 153],
#          [ 60,  29, 150],
#          ...,
#          [ 68,  62, 157],
#          [ 72,  63, 157],
#          [ 63,  66, 159]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN113.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.665395736694336, 'inference': 2472.8548526763916, 'postprocess': 1.2083053588867188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 47,  49, 118],
#          [ 44,  54, 117],
#          [ 42,  56, 118],
#          ...,
#          [ 58,  51, 140],
#          [ 55,  54, 138],
#          [ 58,  52, 137]],
#
#         [[ 48,  45, 119],
#          [ 45,  49, 120],
#          [ 40,  55, 118],
#          ...,
#          [ 56,  54, 139],
#          [ 51,  52, 140],
#          [ 58,  51, 137]],
#
#         [[ 49,  42, 120],
#          [ 45,  47, 122],
#          [ 44,  54, 118],
#          ...,
#          [ 59,  52, 139],
#          [ 56,  52, 138],
#          [ 59,  52, 135]],
#
#         ...,
#
#         [[ 40,  59, 134],
#          [ 45,  58, 133],
#          [ 51,  58, 131],
#          ...,
#          [ 47,   0, 125],
#          [ 42,   0, 124],
#          [ 44,   0, 121]],
#
#         [[ 42,  56, 132],
#          [ 45,  58, 131],
#          [ 48,  59, 129],
#          ...,
#          [ 51,   0, 124],
#          [ 48,   0, 122],
#          [ 48,   0, 120]],
#
#         [[ 42,  58, 131],
#          [ 44,  59, 130],
#          [ 47,  58, 130],
#          ...,
#          [ 55,   0, 122],
#          [ 52,   0, 122],
#          [ 52,   0, 121]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN115.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 8.016109466552734, 'inference': 2399.7457027435303, 'postprocess': 1.4870166778564453},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  45, 138],
#          [ 54,  44, 140],
#          [ 52,  42, 142],
#          ...,
#          [ 63,  52, 152],
#          [ 67,  54, 148],
#          [ 64,  56, 147]],
#
#         [[ 58,  45, 140],
#          [ 56,  44, 142],
#          [ 55,  42, 143],
#          ...,
#          [ 62,  55, 151],
#          [ 67,  54, 149],
#          [ 66,  54, 149]],
#
#         [[ 54,  47, 143],
#          [ 54,  44, 146],
#          [ 52,  47, 144],
#          ...,
#          [ 60,  54, 151],
#          [ 63,  52, 152],
#          [ 62,  55, 151]],
#
#         ...,
#
#         [[ 51,  55, 142],
#          [ 51,  54, 144],
#          [ 52,  54, 142],
#          ...,
#          [ 59,  69, 169],
#          [ 63,  72, 166],
#          [ 64,  74, 166]],
#
#         [[ 47,  56, 144],
#          [ 48,  58, 144],
#          [ 52,  58, 141],
#          ...,
#          [ 62,  71, 166],
#          [ 64,  74, 164],
#          [ 64,  74, 164]],
#
#         [[ 42,  60, 143],
#          [ 47,  59, 144],
#          [ 54,  56, 142],
#          ...,
#          [ 67,  72, 161],
#          [ 67,  72, 163],
#          [ 66,  69, 166]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN116.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.918834686279297, 'inference': 2449.8839378356934, 'postprocess': 1.5418529510498047},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  52, 131],
#          [ 49,  51, 136],
#          [ 47,  52, 137],
#          ...,
#          [ 60,  54, 146],
#          [ 58,  55, 148],
#          [ 59,  55, 151]],
#
#         [[ 59,  49, 129],
#          [ 51,  49, 135],
#          [ 44,  52, 135],
#          ...,
#          [ 60,  51, 146],
#          [ 60,  54, 147],
#          [ 60,  52, 150]],
#
#         [[ 56,  51, 128],
#          [ 49,  49, 132],
#          [ 42,  54, 134],
#          ...,
#          [ 58,  54, 145],
#          [ 60,  52, 147],
#          [ 62,  51, 149]],
#
#         ...,
#
#         [[ 47,  58, 140],
#          [ 51,  58, 140],
#          [ 54,  60, 139],
#          ...,
#          [ 64,  69, 164],
#          [ 69,  69, 161],
#          [ 66,  71, 161]],
#
#         [[ 58,  49, 141],
#          [ 56,  55, 138],
#          [ 54,  60, 138],
#          ...,
#          [ 66,  67, 166],
#          [ 72,  68, 162],
#          [ 66,  73, 161]],
#
#         [[ 62,  52, 139],
#          [ 60,  54, 138],
#          [ 55,  58, 139],
#          ...,
#          [ 69,  67, 164],
#          [ 74,  69, 161],
#          [ 66,  74, 161]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN117.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.05189323425293, 'inference': 2441.479444503784, 'postprocess': 1.3213157653808594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 52,  59, 113],
#          [ 54,  59, 112],
#          [ 55,  58, 115],
#          ...,
#          [ 66,  62, 143],
#          [ 71,  63, 139],
#          [ 68,  67, 136]],
#
#         [[ 59,  56, 114],
#          [ 58,  58, 113],
#          [ 56,  58, 115],
#          ...,
#          [ 66,  67, 137],
#          [ 72,  64, 137],
#          [ 71,  66, 137]],
#
#         [[ 58,  55, 114],
#          [ 55,  56, 116],
#          [ 54,  59, 115],
#          ...,
#          [ 67,  69, 131],
#          [ 68,  66, 136],
#          [ 67,  64, 139]],
#
#         ...,
#
#         [[ 52,  64, 126],
#          [ 55,  66, 126],
#          [ 59,  63, 126],
#          ...,
#          [ 80,  73, 140],
#          [ 82,  72, 141],
#          [ 77,  73, 144]],
#
#         [[ 60,  60, 126],
#          [ 60,  60, 127],
#          [ 62,  62, 124],
#          ...,
#          [ 79,  74, 139],
#          [ 81,  75, 139],
#          [ 75,  74, 142]],
#
#         [[ 67,  59, 123],
#          [ 66,  58, 123],
#          [ 64,  60, 122],
#          ...,
#          [ 79,  73, 140],
#          [ 82,  72, 140],
#          [ 77,  71, 144]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN136.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.088848114013672, 'inference': 2418.330192565918, 'postprocess': 1.0187625885009766},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 58,  52, 122],
#          [ 60,  51, 123],
#          [ 60,  49, 124],
#          ...,
#          [ 72,  56, 146],
#          [ 72,  60, 143],
#          [ 72,  63, 140]],
#
#         [[ 59,  52, 122],
#          [ 58,  52, 122],
#          [ 55,  52, 123],
#          ...,
#          [ 77,  56, 143],
#          [ 77,  59, 140],
#          [ 77,  62, 138]],
#
#         [[ 58,  52, 122],
#          [ 56,  52, 121],
#          [ 52,  56, 120],
#          ...,
#          [ 72,  58, 143],
#          [ 72,  62, 140],
#          [ 72,  64, 137]],
#
#         ...,
#
#         [[ 49,  49, 122],
#          [ 49,  45, 123],
#          [ 49,  44, 125],
#          ...,
#          [ 78,  69, 148],
#          [ 80,  69, 146],
#          [ 79,  72, 144]],
#
#         [[ 47,  48, 124],
#          [ 48,  47, 126],
#          [ 47,  47, 127],
#          ...,
#          [ 83,  69, 146],
#          [ 83,  71, 145],
#          [ 78,  72, 145]],
#
#         [[ 40,  51, 129],
#          [ 42,  49, 129],
#          [ 45,  48, 129],
#          ...,
#          [ 89,  66, 146],
#          [ 87,  68, 145],
#          [ 80,  69, 146]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN137.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 8.187055587768555, 'inference': 2339.428424835205, 'postprocess': 1.692056655883789},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 59,  45, 125],
#          [ 59,  45, 125],
#          [ 59,  48, 125],
#          ...,
#          [ 71,  52, 148],
#          [ 77,  54, 142],
#          [ 81,  55, 136]],
#
#         [[ 56,  47, 124],
#          [ 52,  48, 125],
#          [ 49,  51, 125],
#          ...,
#          [ 74,  54, 143],
#          [ 82,  52, 140],
#          [ 83,  51, 138]],
#
#         [[ 60,  47, 123],
#          [ 59,  47, 124],
#          [ 58,  48, 124],
#          ...,
#          [ 75,  55, 140],
#          [ 78,  52, 140],
#          [ 78,  55, 139]],
#
#         ...,
#
#         [[ 66,  45, 137],
#          [ 68,  47, 137],
#          [ 72,  49, 135],
#          ...,
#          [ 75,  62, 163],
#          [ 75,  63, 160],
#          [ 75,  63, 158]],
#
#         [[ 66,  45, 137],
#          [ 67,  49, 134],
#          [ 67,  52, 134],
#          ...,
#          [ 80,  63, 160],
#          [ 81,  64, 159],
#          [ 78,  63, 158]],
#
#         [[ 66,  49, 133],
#          [ 66,  49, 133],
#          [ 64,  51, 134],
#          ...,
#          [ 87,  59, 159],
#          [ 88,  62, 158],
#          [ 81,  60, 161]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN143.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.134624481201172, 'inference': 2441.849708557129, 'postprocess': 1.474618911743164},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  45, 119],
#          [ 67,  42, 119],
#          [ 69,  44, 118],
#          ...,
#          [ 77,  62, 150],
#          [ 79,  62, 150],
#          [ 79,  60, 152]],
#
#         [[ 63,  42, 119],
#          [ 62,  42, 119],
#          [ 56,  47, 120],
#          ...,
#          [ 78,  64, 150],
#          [ 82,  63, 149],
#          [ 79,  62, 152]],
#
#         [[ 67,  40, 118],
#          [ 67,  42, 116],
#          [ 64,  47, 116],
#          ...,
#          [ 74,  66, 150],
#          [ 75,  64, 152],
#          [ 75,  63, 153]],
#
#         ...,
#
#         [[ 60,  59, 129],
#          [ 67,  58, 127],
#          [ 72,  56, 126],
#          ...,
#          [ 82,  75, 168],
#          [ 80,  79, 167],
#          [ 86,  77, 166]],
#
#         [[ 66,  56, 129],
#          [ 72,  56, 124],
#          [ 75,  54, 125],
#          ...,
#          [ 86,  78, 163],
#          [ 82,  81, 163],
#          [ 85,  78, 166]],
#
#         [[ 71,  54, 128],
#          [ 74,  54, 125],
#          [ 75,  52, 127],
#          ...,
#          [ 88,  74, 164],
#          [ 87,  78, 164],
#          [ 87,  77, 166]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN145.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.664203643798828, 'inference': 2440.9751892089844, 'postprocess': 1.4872550964355469},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  32, 136],
#          [ 66,  27, 134],
#          [ 68,  30, 126],
#          ...,
#          [ 75,  63, 154],
#          [ 79,  62, 151],
#          [ 83,  62, 146]],
#
#         [[ 63,  36, 135],
#          [ 62,  36, 134],
#          [ 60,  36, 129],
#          ...,
#          [ 81,  64, 149],
#          [ 83,  60, 149],
#          [ 87,  59, 148]],
#
#         [[ 58,  39, 136],
#          [ 58,  37, 136],
#          [ 58,  40, 133],
#          ...,
#          [ 77,  67, 148],
#          [ 74,  64, 150],
#          [ 80,  60, 152]],
#
#         ...,
#
#         [[ 32,   0,  87],
#          [ 32,   0,  82],
#          [ 32,   0,  81],
#          ...,
#          [ 83,  59, 159],
#          [ 83,  56, 152],
#          [ 90,  51, 145]],
#
#         [[ 36,   0,  89],
#          [ 36,   0,  86],
#          [ 32,   0,  80],
#          ...,
#          [ 88,  58, 155],
#          [ 89,  56, 148],
#          [ 88,  54, 142]],
#
#         [[ 37,   0,  93],
#          [ 36,   0,  87],
#          [ 30,   0,  82],
#          ...,
#          [ 92,  58, 149],
#          [ 97,  54, 145],
#          [ 86,  54, 143]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN152.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.005878448486328, 'inference': 2647.7620601654053, 'postprocess': 1.4133453369140625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 75,  45,  97],
#          [ 74,  47,  99],
#          [ 73,  48, 101],
#          ...,
#          [ 63,  64, 155],
#          [ 67,  66, 151],
#          [ 74,  66, 146]],
#
#         [[ 77,  44, 102],
#          [ 71,  47, 106],
#          [ 66,  48, 110],
#          ...,
#          [ 66,  69, 149],
#          [ 73,  64, 150],
#          [ 79,  60, 149]],
#
#         [[ 72,  45, 109],
#          [ 67,  47, 113],
#          [ 60,  49, 117],
#          ...,
#          [ 71,  69, 145],
#          [ 74,  62, 149],
#          [ 75,  59, 153]],
#
#         ...,
#
#         [[ 56,  62, 132],
#          [ 62,  62, 131],
#          [ 66,  62, 129],
#          ...,
#          [ 74,  73, 161],
#          [ 68,  75, 163],
#          [ 73,  74, 161]],
#
#         [[ 64,  58, 132],
#          [ 64,  59, 131],
#          [ 64,  62, 130],
#          ...,
#          [ 74,  75, 161],
#          [ 73,  77, 161],
#          [ 73,  75, 163]],
#
#         [[ 73,  56, 128],
#          [ 68,  59, 129],
#          [ 63,  60, 130],
#          ...,
#          [ 74,  75, 165],
#          [ 79,  75, 163],
#          [ 75,  75, 163]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN200.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.7457427978515625, 'inference': 2459.0206146240234, 'postprocess': 1.1878013610839844},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  39, 113],
#          [ 60,  40, 114],
#          [ 56,  42, 115],
#          ...,
#          [ 72,  54, 138],
#          [ 74,  52, 135],
#          [ 77,  54, 130]],
#
#         [[ 67,  37, 111],
#          [ 64,  39, 112],
#          [ 60,  42, 113],
#          ...,
#          [ 67,  54, 138],
#          [ 75,  51, 133],
#          [ 77,  51, 130]],
#
#         [[ 63,  40, 110],
#          [ 62,  44, 110],
#          [ 58,  47, 110],
#          ...,
#          [ 67,  56, 135],
#          [ 71,  52, 132],
#          [ 74,  55, 128]],
#
#         ...,
#
#         [[ 55,  58, 124],
#          [ 60,  58, 120],
#          [ 66,  58, 118],
#          ...,
#          [ 39,   0,  77],
#          [ 39,   0,  78],
#          [ 39,   0,  78]],
#
#         [[ 58,  54, 123],
#          [ 60,  58, 118],
#          [ 62,  58, 117],
#          ...,
#          [ 44,   0,  74],
#          [ 45,   0,  73],
#          [ 44,   0,  73]],
#
#         [[ 58,  52, 123],
#          [ 58,  52, 122],
#          [ 58,  52, 121],
#          ...,
#          [ 47,   0,  75],
#          [ 51,   0,  72],
#          [ 48,   0,  72]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN201.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.678031921386719, 'inference': 2411.1170768737793, 'postprocess': 1.4460086822509766},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 66,  55, 121],
#          [ 66,  59, 119],
#          [ 63,  59, 125],
#          ...,
#          [ 72,  52, 129],
#          [ 69,  51, 129],
#          [ 69,  54, 128]],
#
#         [[ 69,  45, 127],
#          [ 64,  51, 126],
#          [ 58,  55, 129],
#          ...,
#          [ 78,  54, 122],
#          [ 79,  49, 123],
#          [ 77,  49, 125]],
#
#         [[ 51,  32, 137],
#          [ 48,  37, 138],
#          [ 45,  45, 136],
#          ...,
#          [ 78,  56, 115],
#          [ 79,  52, 119],
#          [ 78,  48, 124]],
#
#         ...,
#
#         [[ 48,  64, 141],
#          [ 56,  62, 142],
#          [ 66,  60, 140],
#          ...,
#          [ 85,  58, 143],
#          [ 82,  60, 138],
#          [ 81,  62, 133]],
#
#         [[ 49,  64, 143],
#          [ 58,  60, 146],
#          [ 66,  60, 145],
#          ...,
#          [ 85,  56, 146],
#          [ 87,  59, 135],
#          [ 82,  64, 127]],
#
#         [[ 55,  66, 141],
#          [ 62,  63, 141],
#          [ 68,  64, 140],
#          ...,
#          [ 87,  58, 144],
#          [ 91,  58, 134],
#          [ 83,  62, 128]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN202.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.072158813476562, 'inference': 2447.176694869995, 'postprocess': 1.7902851104736328},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  47, 109],
#          [ 55,  47, 112],
#          [ 55,  48, 113],
#          ...,
#          [ 58,  52, 152],
#          [ 66,  55, 146],
#          [ 69,  60, 140]],
#
#         [[ 55,  47, 109],
#          [ 54,  45, 112],
#          [ 48,  48, 115],
#          ...,
#          [ 58,  55, 150],
#          [ 62,  55, 148],
#          [ 66,  56, 145]],
#
#         [[ 54,  45, 111],
#          [ 49,  47, 112],
#          [ 42,  51, 116],
#          ...,
#          [ 59,  55, 150],
#          [ 62,  54, 150],
#          [ 66,  54, 149]],
#
#         ...,
#
#         [[ 51,  54, 133],
#          [ 58,  54, 130],
#          [ 63,  54, 128],
#          ...,
# ...
#
#         ...,
#
#         [[ 42,  62, 129],
#          [ 45,  60, 129],
#          [ 51,  59, 129],
#          ...,
#          [ 54,  68, 137],
#          [ 56,  67, 134],
#          [ 60,  64, 133]],
#
#         [[ 47,  59, 129],
#          [ 47,  56, 132],
#          [ 49,  58, 130],
#          ...,
#          [ 54,  66, 138],
#          [ 56,  67, 135],
#          [ 55,  67, 132]],
#
#         [[ 52,  56, 128],
#          [ 51,  56, 129],
#          [ 49,  56, 129],
#          ...,
#          [ 55,  64, 139],
#          [ 55,  68, 134],
#          [ 49,  68, 134]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN360.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.374950408935547, 'inference': 2446.817636489868, 'postprocess': 1.4996528625488281},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 45,  51, 128],
#          [ 48,  47, 130],
#          [ 51,  48, 129],
#          ...,
#          [ 47,  49, 138],
#          [ 54,  51, 135],
#          [ 54,  52, 135]],
#
#         [[ 54,  49, 125],
#          [ 55,  48, 126],
#          [ 55,  48, 126],
#          ...,
#          [ 44,  49, 137],
#          [ 54,  51, 134],
#          [ 55,  51, 134]],
#
#         [[ 48,  51, 125],
#          [ 51,  51, 124],
#          [ 52,  51, 126],
#          ...,
#          [ 40,  51, 136],
#          [ 52,  51, 135],
#          [ 52,  49, 135]],
#
#         ...,
#
#         [[ 39,  59, 128],
#          [ 42,  59, 127],
#          [ 44,  58, 129],
#          ...,
#          [ 40,  58, 136],
#          [ 45,  56, 135],
#          [ 51,  52, 135]],
#
#         [[ 47,  56, 128],
#          [ 47,  59, 125],
#          [ 44,  60, 127],
#          ...,
#          [ 47,  56, 133],
#          [ 48,  56, 134],
#          [ 49,  54, 135]],
#
#         [[ 51,  58, 126],
#          [ 49,  58, 125],
#          [ 47,  58, 125],
#          ...,
#          [ 52,  55, 132],
#          [ 49,  58, 132],
#          [ 48,  58, 133]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN366.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 10.824918746948242, 'inference': 2438.2824897766113, 'postprocess': 1.3926029205322266},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 48,  64, 140],
#          [ 51,  63, 139],
#          [ 52,  62, 140],
#          ...,
#          [ 52,  59, 152],
#          [ 48,  64, 151],
#          [ 54,  67, 148]],
#
#         [[ 49,  63, 139],
#          [ 47,  64, 139],
#          [ 42,  66, 140],
#          ...,
#          [ 51,  62, 149],
#          [ 51,  63, 149],
#          [ 58,  63, 148]],
#
#         [[ 48,  66, 137],
#          [ 42,  67, 140],
#          [ 39,  68, 140],
#          ...,
#          [ 48,  67, 148],
#          [ 48,  64, 150],
#          [ 54,  60, 153]],
#
#         ...,
#
#         [[ 48,  62, 141],
#          [ 48,  60, 143],
#          [ 51,  59, 143],
#          ...,
#          [ 52,  67, 146],
#          [ 47,  67, 146],
#          [ 48,  68, 146]],
#
#         [[ 44,  62, 142],
#          [ 45,  62, 141],
#          [ 49,  60, 141],
#          ...,
#          [ 49,  63, 148],
#          [ 51,  64, 147],
#          [ 48,  66, 148]],
#
#         [[ 36,  66, 142],
#          [ 40,  66, 141],
#          [ 47,  63, 141],
#          ...,
#          [ 49,  63, 148],
#          [ 56,  62, 147],
#          [ 47,  64, 147]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN367.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.436223983764648, 'inference': 2487.192392349243, 'postprocess': 1.4865398406982422},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 48,  59, 130],
#          [ 45,  59, 130],
#          [ 40,  59, 132],
#          ...,
#          [ 49,  60, 142],
#          [ 55,  59, 138],
#          [ 56,  58, 136]],
#
#         [[ 51,  56, 129],
#          [ 48,  56, 130],
#          [ 44,  59, 131],
#          ...,
#          [ 58,  60, 137],
#          [ 60,  56, 137],
#          [ 59,  55, 136]],
#
#         [[ 52,  56, 129],
#          [ 49,  59, 129],
#          [ 45,  62, 129],
#          ...,
#          [ 52,  63, 134],
#          [ 55,  59, 135],
#          [ 55,  59, 135]],
#
#         ...,
#
#         [[ 27,  66, 133],
#          [ 39,  66, 130],
#          [ 52,  64, 126],
#          ...,
#          [ 51,  64, 139],
#          [ 54,  64, 136],
#          [ 51,  66, 134]],
#
#         [[ 34,  63, 132],
#          [ 44,  62, 131],
#          [ 54,  60, 129],
#          ...,
#          [ 48,  64, 140],
#          [ 48,  68, 137],
#          [ 49,  66, 136]],
#
#         [[ 37,  60, 133],
#          [ 47,  59, 131],
#          [ 56,  56, 129],
#          ...,
#          [ 48,  67, 135],
#          [ 47,  67, 135],
#          [ 49,  66, 134]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN368.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.685422897338867, 'inference': 2456.3539028167725, 'postprocess': 1.5344619750976562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  55, 116],
#          [ 59,  58, 116],
#          [ 58,  58, 115],
#          ...,
#          [ 60,  63, 123],
#          [ 59,  60, 125],
#          [ 58,  60, 127]],
#
#         [[ 56,  58, 116],
#          [ 54,  59, 117],
#          [ 54,  60, 116],
#          ...,
#          [ 59,  60, 127],
#          [ 59,  58, 128],
#          [ 59,  56, 129]],
#
#         [[ 52,  58, 117],
#          [ 52,  59, 119],
#          [ 54,  60, 116],
#          ...,
#          [ 54,  60, 129],
#          [ 54,  59, 130],
#          [ 58,  59, 129]],
#
#         ...,
#
#         [[ 51,  59, 121],
#          [ 55,  60, 119],
#          [ 60,  62, 116],
#          ...,
#          [ 56,  40, 119],
#          [ 54,  40, 121],
#          [ 56,  42, 122]],
#
#         [[ 47,  60, 123],
#          [ 51,  59, 123],
#          [ 58,  58, 120],
#          ...,
#          [ 56,  39, 119],
#          [ 54,  40, 120],
#          [ 52,  44, 121]],
#
#         [[ 48,  60, 120],
#          [ 52,  59, 120],
#          [ 56,  59, 117],
#          ...,
#          [ 58,  39, 114],
#          [ 54,  42, 118],
#          [ 49,  45, 121]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN369.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.492252349853516, 'inference': 2662.019729614258, 'postprocess': 1.4874935150146484},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 52,  59, 118],
#          [ 56,  56, 119],
#          [ 58,  58, 118],
#          ...,
#          [ 56,  54, 123],
#          [ 54,  54, 126],
#          [ 56,  58, 125]],
#
#         [[ 62,  56, 117],
#          [ 59,  58, 117],
#          [ 56,  59, 116],
#          ...,
#          [ 59,  54, 122],
#          [ 54,  54, 125],
#          [ 56,  59, 125]],
#
#         [[ 55,  60, 117],
#          [ 56,  60, 117],
#          [ 58,  60, 116],
#          ...,
#          [ 59,  58, 119],
#          [ 52,  60, 123],
#          [ 52,  64, 124]],
#
#         ...,
#
#         [[ 51,  60, 117],
#          [ 58,  60, 114],
#          [ 63,  59, 116],
#          ...,
#          [ 49,  67, 120],
#          [ 48,  68, 118],
#          [ 54,  67, 115]],
#
#         [[ 55,  56, 119],
#          [ 55,  58, 118],
#          [ 56,  60, 118],
#          ...,
#          [ 54,  66, 118],
#          [ 52,  67, 116],
#          [ 56,  64, 113]],
#
#         [[ 55,  59, 117],
#          [ 54,  60, 115],
#          [ 51,  62, 116],
#          ...,
#          [ 58,  63, 120],
#          [ 59,  62, 118],
#          [ 58,  60, 117]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN374.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.098623275756836, 'inference': 2462.341785430908, 'postprocess': 1.4481544494628906},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  62, 122],
#          [ 64,  62, 121],
#          [ 67,  60, 121],
#          ...,
#          [ 56,  69, 129],
#          [ 63,  69, 126],
#          [ 64,  68, 126]],
#
#         [[ 63,  60, 123],
#          [ 60,  62, 123],
#          [ 58,  62, 123],
#          ...,
#          [ 55,  72, 129],
#          [ 69,  67, 127],
#          [ 68,  66, 127]],
#
#         [[ 55,  64, 123],
#          [ 55,  62, 127],
#          [ 55,  62, 127],
#          ...,
#          [ 55,  71, 128],
#          [ 59,  67, 129],
#          [ 59,  66, 131]],
#
#         ...,
#
#         [[ 52,  63, 122],
#          [ 56,  64, 122],
#          [ 62,  64, 119],
#          ...,
#          [ 52,  71, 129],
#          [ 49,  72, 129],
#          [ 56,  69, 128]],
#
#         [[ 55,  62, 124],
#          [ 56,  63, 124],
#          [ 58,  64, 121],
#          ...,
#          [ 55,  69, 129],
#          [ 54,  72, 128],
#          [ 55,  71, 127]],
#
#         [[ 56,  63, 122],
#          [ 55,  63, 124],
#          [ 55,  66, 121],
#          ...,
#          [ 59,  68, 129],
#          [ 60,  69, 127],
#          [ 55,  69, 127]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN375.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.684417724609375, 'inference': 2453.8397789001465, 'postprocess': 1.4748573303222656},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  64, 128],
#          [ 60,  64, 127],
#          [ 58,  66, 127],
#          ...,
#          [ 64,  72, 133],
#          [ 64,  71, 132],
#          [ 68,  69, 130]],
#
#         [[ 60,  62, 129],
#          [ 59,  63, 129],
#          [ 56,  66, 129],
#          ...,
#          [ 67,  69, 133],
#          [ 72,  68, 131],
#          [ 69,  67, 133]],
#
#         [[ 60,  62, 129],
#          [ 58,  62, 131],
#          [ 55,  66, 131],
#          ...,
#          [ 63,  72, 134],
#          [ 67,  69, 133],
#          [ 67,  68, 135]],
#
#         ...,
#
#         [[ 56,  66, 124],
#          [ 59,  68, 124],
#          [ 59,  71, 122],
#          ...,
#          [ 64,  68, 132],
#          [ 62,  71, 133],
#          [ 59,  72, 134]],
#
#         [[ 59,  63, 126],
#          [ 59,  67, 122],
#          [ 58,  71, 123],
#          ...,
#          [ 66,  69, 131],
#          [ 64,  71, 133],
#          [ 56,  72, 136]],
#
#         [[ 55,  64, 128],
#          [ 56,  66, 126],
#          [ 56,  67, 125],
#          ...,
#          [ 64,  69, 133],
#          [ 67,  69, 133],
#          [ 55,  73, 135]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN376.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.140108108520508, 'inference': 2513.6263370513916, 'postprocess': 1.558065414428711},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  59, 119],
#          [ 49,  63, 118],
#          [ 48,  63, 118],
#          ...,
#          [ 54,  63, 134],
#          [ 58,  64, 129],
#          [ 59,  68, 123]],
#
#         [[ 59,  59, 118],
#          [ 54,  60, 119],
#          [ 51,  62, 119],
#          ...,
#          [ 58,  67, 127],
#          [ 62,  66, 126],
#          [ 60,  67, 125]],
#
#         [[ 55,  60, 118],
#          [ 52,  60, 120],
#          [ 51,  60, 120],
#          ...,
#          [ 59,  69, 122],
#          [ 59,  68, 123],
#          [ 59,  66, 126]],
#
#         ...,
#
#         [[ 47,  66, 116],
#          [ 54,  64, 115],
#          [ 63,  63, 112],
#          ...,
#          [ 51,  72, 126],
#          [ 48,  72, 126],
#          [ 51,  71, 126]],
#
#         [[ 45,  64, 117],
#          [ 52,  63, 116],
#          [ 58,  62, 113],
#          ...,
#          [ 55,  71, 125],
#          [ 55,  72, 124],
#          [ 54,  69, 124]],
#
#         [[ 42,  66, 117],
#          [ 47,  60, 119],
#          [ 51,  62, 116],
#          ...,
#          [ 60,  68, 125],
#          [ 64,  68, 123],
#          [ 58,  67, 124]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN377.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.432409286499023, 'inference': 2489.588499069214, 'postprocess': 1.8048286437988281},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 56,  62, 131],
#          [ 55,  62, 130],
#          [ 54,  63, 130],
#          ...,
#          [ 56,  67, 141],
#          [ 58,  68, 137],
#          [ 63,  71, 131]],
#
#         [[ 60,  62, 129],
#          [ 56,  60, 131],
#          [ 54,  62, 130],
#          ...,
#          [ 55,  71, 139],
#          [ 55,  69, 138],
#          [ 63,  68, 136]],
#
#         [[ 54,  63, 129],
#          [ 54,  63, 130],
#          [ 54,  63, 129],
#          ...,
#          [ 51,  75, 136],
#          [ 51,  73, 138],
#          [ 56,  69, 140]],
#
#         ...,
#
#         [[ 36,  68, 132],
#          [ 44,  69, 129],
#          [ 52,  67, 128],
#          ...,
#          [ 45,  68, 139],
#          [ 47,  68, 139],
#          [ 56,  66, 137]],
#
#         [[ 44,  66, 131],
#          [ 49,  67, 128],
#          [ 54,  67, 127],
#          ...,
#          [ 52,  67, 136],
#          [ 51,  68, 137],
#          [ 56,  66, 138]],
#
#         [[ 51,  66, 128],
#          [ 54,  64, 127],
#          [ 54,  67, 126],
#          ...,
#          [ 59,  64, 133],
#          [ 58,  66, 135],
#          [ 56,  64, 136]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN382.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.345148086547852, 'inference': 2462.920665740967, 'postprocess': 1.7633438110351562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 51,  58, 122],
#          [ 51,  60, 120],
#          [ 52,  60, 119],
#          ...,
#          [ 52,  62, 128],
#          [ 55,  64, 123],
#          [ 58,  67, 117]],
#
#         [[ 48,  58, 122],
#          [ 49,  59, 122],
#          [ 51,  59, 121],
#          ...,
#          [ 55,  63, 126],
#          [ 58,  63, 124],
#          [ 60,  62, 122]],
#
#         [[ 49,  60, 120],
#          [ 48,  59, 123],
#          [ 49,  60, 121],
#          ...,
#          [ 54,  66, 124],
#          [ 54,  62, 127],
#          [ 56,  59, 129]],
#
#         ...,
#
#         [[ 45,  59, 118],
#          [ 48,  59, 119],
#          [ 54,  58, 118],
#          ...,
#          [ 47,  63, 129],
#          [ 42,  66, 128],
#          [ 45,  64, 126]],
#
#         [[ 49,  58, 118],
#          [ 51,  58, 118],
#          [ 54,  58, 118],
#          ...,
#          [ 51,  60, 129],
#          [ 49,  64, 126],
#          [ 49,  66, 123]],
#
#         [[ 52,  58, 116],
#          [ 54,  56, 117],
#          [ 55,  58, 116],
#          ...,
#          [ 58,  59, 127],
#          [ 59,  60, 125],
#          [ 55,  63, 124]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN383.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 11.415481567382812, 'inference': 2467.9951667785645, 'postprocess': 1.4872550964355469}]

# %%
model_MN.predict(source="/kaggle/input/detectionbnmn-3classes/images/test", save=False, show_conf=False, show_labels=False, save_txt=True)
# Out:
# image 1/268 /kaggle/input/detectionbnmn-3classes/images/test/BN112.png: 832x1088 (no detections), 766.4ms
# image 2/268 /kaggle/input/detectionbnmn-3classes/images/test/BN113.png: 832x1088 (no detections), 746.9ms
# image 3/268 /kaggle/input/detectionbnmn-3classes/images/test/BN115.png: 832x1088 (no detections), 760.7ms
# image 4/268 /kaggle/input/detectionbnmn-3classes/images/test/BN116.png: 832x1088 (no detections), 755.4ms
# image 5/268 /kaggle/input/detectionbnmn-3classes/images/test/BN117.png: 832x1088 (no detections), 802.1ms
# image 6/268 /kaggle/input/detectionbnmn-3classes/images/test/BN136.png: 832x1088 (no detections), 772.9ms
# image 7/268 /kaggle/input/detectionbnmn-3classes/images/test/BN137.png: 832x1088 (no detections), 745.7ms
# image 8/268 /kaggle/input/detectionbnmn-3classes/images/test/BN143.png: 832x1088 (no detections), 801.9ms
# image 9/268 /kaggle/input/detectionbnmn-3classes/images/test/BN145.png: 832x1088 (no detections), 763.6ms
# image 10/268 /kaggle/input/detectionbnmn-3classes/images/test/BN152.png: 832x1088 2 MNs, 778.2ms
# image 11/268 /kaggle/input/detectionbnmn-3classes/images/test/BN200.png: 832x1088 (no detections), 828.6ms
# image 12/268 /kaggle/input/detectionbnmn-3classes/images/test/BN201.png: 832x1088 (no detections), 757.7ms
# image 13/268 /kaggle/input/detectionbnmn-3classes/images/test/BN202.png: 832x1088 (no detections), 728.9ms
# image 14/268 /kaggle/input/detectionbnmn-3classes/images/test/BN205.png: 832x1088 (no detections), 772.7ms
# image 15/268 /kaggle/input/detectionbnmn-3classes/images/test/BN207.png: 832x1088 (no detections), 777.2ms
# image 16/268 /kaggle/input/detectionbnmn-3classes/images/test/BN226.png: 832x1088 1 MN, 731.7ms
# image 17/268 /kaggle/input/detectionbnmn-3classes/images/test/BN227.png: 832x1088 1 MN, 750.7ms
# image 18/268 /kaggle/input/detectionbnmn-3classes/images/test/BN229.png: 832x1088 (no detections), 794.7ms
# image 19/268 /kaggle/input/detectionbnmn-3classes/images/test/BN232.png: 832x1088 (no detections), 803.7ms
# image 20/268 /kaggle/input/detectionbnmn-3classes/images/test/BN261.png: 832x1088 (no detections), 746.7ms
# image 21/268 /kaggle/input/detectionbnmn-3classes/images/test/BN265.png: 832x1088 (no detections), 779.9ms
# image 22/268 /kaggle/input/detectionbnmn-3classes/images/test/BN269.png: 832x1088 (no detections), 760.4ms
# image 23/268 /kaggle/input/detectionbnmn-3classes/images/test/BN270.png: 832x1088 1 MN, 794.2ms
# image 24/268 /kaggle/input/detectionbnmn-3classes/images/test/BN272.png: 832x1088 (no detections), 810.3ms
# image 25/268 /kaggle/input/detectionbnmn-3classes/images/test/BN274.png: 832x1088 (no detections), 745.4ms
# image 26/268 /kaggle/input/detectionbnmn-3classes/images/test/BN275.png: 832x1088 (no detections), 794.3ms
# image 27/268 /kaggle/input/detectionbnmn-3classes/images/test/BN276.png: 832x1088 (no detections), 792.2ms
# image 28/268 /kaggle/input/detectionbnmn-3classes/images/test/BN302.png: 832x1088 (no detections), 756.8ms
# image 29/268 /kaggle/input/detectionbnmn-3classes/images/test/BN303.png: 832x1088 (no detections), 796.5ms
# image 30/268 /kaggle/input/detectionbnmn-3classes/images/test/BN304.png: 832x1088 (no detections), 770.0ms
# image 31/268 /kaggle/input/detectionbnmn-3classes/images/test/BN305.png: 832x1088 (no detections), 814.4ms
# image 32/268 /kaggle/input/detectionbnmn-3classes/images/test/BN306.png: 832x1088 1 MN, 712.3ms
# image 33/268 /kaggle/input/detectionbnmn-3classes/images/test/BN307.png: 832x1088 (no detections), 810.8ms
# image 34/268 /kaggle/input/detectionbnmn-3classes/images/test/BN311.png: 832x1088 (no detections), 798.2ms
# image 35/268 /kaggle/input/detectionbnmn-3classes/images/test/BN329.png: 832x1088 (no detections), 765.7ms
# image 36/268 /kaggle/input/detectionbnmn-3classes/images/test/BN330.png: 832x1088 (no detections), 760.7ms
# image 37/268 /kaggle/input/detectionbnmn-3classes/images/test/BN331.png: 832x1088 1 MN, 791.2ms
# image 38/268 /kaggle/input/detectionbnmn-3classes/images/test/BN332.png: 832x1088 (no detections), 861.0ms
# image 39/268 /kaggle/input/detectionbnmn-3classes/images/test/BN333.png: 832x1088 (no detections), 724.6ms
# image 40/268 /kaggle/input/detectionbnmn-3classes/images/test/BN337.png: 832x1088 (no detections), 768.7ms
# image 41/268 /kaggle/input/detectionbnmn-3classes/images/test/BN343.png: 832x1088 (no detections), 810.3ms
# image 42/268 /kaggle/input/detectionbnmn-3classes/images/test/BN346.png: 832x1088 (no detections), 828.0ms
# image 43/268 /kaggle/input/detectionbnmn-3classes/images/test/BN347.png: 832x1088 (no detections), 806.0ms
# image 44/268 /kaggle/input/detectionbnmn-3classes/images/test/BN349.png: 832x1088 (no detections), 752.8ms
# image 45/268 /kaggle/input/detectionbnmn-3classes/images/test/BN351.png: 832x1088 (no detections), 751.2ms
# image 46/268 /kaggle/input/detectionbnmn-3classes/images/test/BN352.png: 832x1088 (no detections), 794.3ms
# image 47/268 /kaggle/input/detectionbnmn-3classes/images/test/BN353.png: 832x1088 (no detections), 814.3ms
# image 48/268 /kaggle/input/detectionbnmn-3classes/images/test/BN373.png: 832x1088 (no detections), 786.5ms
# image 49/268 /kaggle/input/detectionbnmn-3classes/images/test/BN374.png: 832x1088 (no detections), 720.2ms
# image 50/268 /kaggle/input/detectionbnmn-3classes/images/test/BN375.png: 832x1088 (no detections), 723.1ms
# image 51/268 /kaggle/input/detectionbnmn-3classes/images/test/BN376.png: 832x1088 (no detections), 741.1ms
# image 52/268 /kaggle/input/detectionbnmn-3classes/images/test/BN377.png: 832x1088 (no detections), 726.0ms
# image 53/268 /kaggle/input/detectionbnmn-3classes/images/test/BN378.png: 832x1088 (no detections), 781.0ms
# image 54/268 /kaggle/input/detectionbnmn-3classes/images/test/BN379.png: 832x1088 (no detections), 712.7ms
# image 55/268 /kaggle/input/detectionbnmn-3classes/images/test/BN380.png: 832x1088 (no detections), 732.1ms
# image 56/268 /kaggle/input/detectionbnmn-3classes/images/test/BN381.png: 832x1088 (no detections), 746.6ms
# image 57/268 /kaggle/input/detectionbnmn-3classes/images/test/BN382.png: 832x1088 (no detections), 740.5ms
# image 58/268 /kaggle/input/detectionbnmn-3classes/images/test/BN383.png: 832x1088 (no detections), 746.6ms
# image 59/268 /kaggle/input/detectionbnmn-3classes/images/test/BN384.png: 832x1088 (no detections), 748.8ms
# image 60/268 /kaggle/input/detectionbnmn-3classes/images/test/BN385.png: 832x1088 (no detections), 807.3ms
# image 61/268 /kaggle/input/detectionbnmn-3classes/images/test/BN389.png: 832x1088 (no detections), 728.7ms
# image 62/268 /kaggle/input/detectionbnmn-3classes/images/test/BN413.png: 832x1088 (no detections), 728.5ms
# image 63/268 /kaggle/input/detectionbnmn-3classes/images/test/BN414.png: 832x1088 (no detections), 742.3ms
# image 64/268 /kaggle/input/detectionbnmn-3classes/images/test/BN415.png: 832x1088 1 MN, 755.0ms
# image 65/268 /kaggle/input/detectionbnmn-3classes/images/test/BN416.png: 832x1088 (no detections), 754.5ms
# image 66/268 /kaggle/input/detectionbnmn-3classes/images/test/BN417.png: 832x1088 (no detections), 724.7ms
# image 67/268 /kaggle/input/detectionbnmn-3classes/images/test/BN418.png: 832x1088 (no detections), 744.1ms
# image 68/268 /kaggle/input/detectionbnmn-3classes/images/test/BN419.png: 832x1088 (no detections), 825.3ms
# image 69/268 /kaggle/input/detectionbnmn-3classes/images/test/BN420.png: 832x1088 (no detections), 811.5ms
# image 70/268 /kaggle/input/detectionbnmn-3classes/images/test/BN439.png: 832x1088 (no detections), 763.3ms
# image 71/268 /kaggle/input/detectionbnmn-3classes/images/test/BN440.png: 832x1088 (no detections), 748.9ms
# image 72/268 /kaggle/input/detectionbnmn-3classes/images/test/BN441.png: 832x1088 (no detections), 717.8ms
# image 73/268 /kaggle/input/detectionbnmn-3classes/images/test/BN442.png: 832x1088 (no detections), 732.7ms
# image 74/268 /kaggle/input/detectionbnmn-3classes/images/test/BN443.png: 832x1088 (no detections), 735.7ms
# image 75/268 /kaggle/input/detectionbnmn-3classes/images/test/BN444.png: 832x1088 (no detections), 742.0ms
# image 76/268 /kaggle/input/detectionbnmn-3classes/images/test/BN446.png: 832x1088 (no detections), 729.0ms
# image 77/268 /kaggle/input/detectionbnmn-3classes/images/test/BN447.png: 832x1088 (no detections), 732.8ms
# image 78/268 /kaggle/input/detectionbnmn-3classes/images/test/BN448.png: 832x1088 (no detections), 751.1ms
# image 79/268 /kaggle/input/detectionbnmn-3classes/images/test/BN468.png: 832x1088 (no detections), 764.9ms
# image 80/268 /kaggle/input/detectionbnmn-3classes/images/test/BN469.png: 832x1088 (no detections), 789.6ms
# image 81/268 /kaggle/input/detectionbnmn-3classes/images/test/BN470.png: 832x1088 (no detections), 722.4ms
# image 82/268 /kaggle/input/detectionbnmn-3classes/images/test/BN472.png: 832x1088 1 MN, 757.3ms
# image 83/268 /kaggle/input/detectionbnmn-3classes/images/test/BN473.png: 832x1088 1 MN, 747.3ms
# image 84/268 /kaggle/input/detectionbnmn-3classes/images/test/BN474.png: 832x1088 (no detections), 779.5ms
# image 85/268 /kaggle/input/detectionbnmn-3classes/images/test/BN475.png: 832x1088 (no detections), 725.2ms
# image 86/268 /kaggle/input/detectionbnmn-3classes/images/test/BN476.png: 832x1088 1 MN, 738.0ms
# image 87/268 /kaggle/input/detectionbnmn-3classes/images/test/BN477.png: 832x1088 1 MN, 730.7ms
# image 88/268 /kaggle/input/detectionbnmn-3classes/images/test/BN500.png: 832x1088 1 MN, 783.2ms
# image 89/268 /kaggle/input/detectionbnmn-3classes/images/test/BN501.png: 832x1088 (no detections), 779.5ms
# image 90/268 /kaggle/input/detectionbnmn-3classes/images/test/BN502.png: 832x1088 (no detections), 750.0ms
# image 91/268 /kaggle/input/detectionbnmn-3classes/images/test/BN504.png: 832x1088 (no detections), 749.0ms
# image 92/268 /kaggle/input/detectionbnmn-3classes/images/test/BN506.png: 832x1088 (no detections), 715.9ms
# image 93/268 /kaggle/input/detectionbnmn-3classes/images/test/BN507.png: 832x1088 (no detections), 754.0ms
# image 94/268 /kaggle/input/detectionbnmn-3classes/images/test/BN508.png: 832x1088 (no detections), 757.2ms
# image 95/268 /kaggle/input/detectionbnmn-3classes/images/test/BN509.png: 832x1088 1 MN, 727.8ms
# image 96/268 /kaggle/input/detectionbnmn-3classes/images/test/BN53.png: 832x1088 (no detections), 739.8ms
# image 97/268 /kaggle/input/detectionbnmn-3classes/images/test/BN531.png: 832x1088 (no detections), 761.6ms
# image 98/268 /kaggle/input/detectionbnmn-3classes/images/test/BN532.png: 832x1088 (no detections), 726.7ms
# image 99/268 /kaggle/input/detectionbnmn-3classes/images/test/BN533.png: 832x1088 (no detections), 748.6ms
# image 100/268 /kaggle/input/detectionbnmn-3classes/images/test/BN534.png: 832x1088 (no detections), 744.2ms
# image 101/268 /kaggle/input/detectionbnmn-3classes/images/test/BN535.png: 832x1088 (no detections), 791.0ms
# image 102/268 /kaggle/input/detectionbnmn-3classes/images/test/BN536.png: 832x1088 (no detections), 715.0ms
# image 103/268 /kaggle/input/detectionbnmn-3classes/images/test/BN54.png: 832x1088 1 MN, 746.3ms
# image 104/268 /kaggle/input/detectionbnmn-3classes/images/test/BN554.png: 832x1088 (no detections), 800.1ms
# image 105/268 /kaggle/input/detectionbnmn-3classes/images/test/BN555.png: 832x1088 1 MN, 809.3ms
# image 106/268 /kaggle/input/detectionbnmn-3classes/images/test/BN556.png: 832x1088 (no detections), 738.7ms
# image 107/268 /kaggle/input/detectionbnmn-3classes/images/test/BN557.png: 832x1088 (no detections), 733.4ms
# image 108/268 /kaggle/input/detectionbnmn-3classes/images/test/BN558.png: 832x1088 1 MN, 764.1ms
# image 109/268 /kaggle/input/detectionbnmn-3classes/images/test/BN559.png: 832x1088 (no detections), 742.8ms
# image 110/268 /kaggle/input/detectionbnmn-3classes/images/test/BN56.png: 832x1088 (no detections), 738.9ms
# image 111/268 /kaggle/input/detectionbnmn-3classes/images/test/BN560.png: 832x1088 (no detections), 751.7ms
# image 112/268 /kaggle/input/detectionbnmn-3classes/images/test/BN561.png: 832x1088 (no detections), 744.4ms
# image 113/268 /kaggle/input/detectionbnmn-3classes/images/test/BN562.png: 832x1088 (no detections), 755.6ms
# image 114/268 /kaggle/input/detectionbnmn-3classes/images/test/BN583.png: 832x1088 (no detections), 731.6ms
# image 115/268 /kaggle/input/detectionbnmn-3classes/images/test/BN584.png: 832x1088 (no detections), 726.7ms
# image 116/268 /kaggle/input/detectionbnmn-3classes/images/test/BN585.png: 832x1088 1 MN, 738.2ms
# image 117/268 /kaggle/input/detectionbnmn-3classes/images/test/BN586.png: 832x1088 (no detections), 751.0ms
# image 118/268 /kaggle/input/detectionbnmn-3classes/images/test/BN587.png: 832x1088 (no detections), 775.9ms
# image 119/268 /kaggle/input/detectionbnmn-3classes/images/test/BN588.png: 832x1088 (no detections), 793.9ms
# image 120/268 /kaggle/input/detectionbnmn-3classes/images/test/BN589.png: 832x1088 (no detections), 740.6ms
# image 121/268 /kaggle/input/detectionbnmn-3classes/images/test/BN607.png: 832x1088 (no detections), 708.3ms
# image 122/268 /kaggle/input/detectionbnmn-3classes/images/test/BN608.png: 832x1088 (no detections), 707.7ms
# image 123/268 /kaggle/input/detectionbnmn-3classes/images/test/BN610.png: 832x1088 1 MN, 712.1ms
# image 124/268 /kaggle/input/detectionbnmn-3classes/images/test/BN611.png: 832x1088 (no detections), 749.0ms
# image 125/268 /kaggle/input/detectionbnmn-3classes/images/test/BN612.png: 832x1088 (no detections), 729.6ms
# image 126/268 /kaggle/input/detectionbnmn-3classes/images/test/BN613.png: 832x1088 (no detections), 737.8ms
# image 127/268 /kaggle/input/detectionbnmn-3classes/images/test/BN623.png: 832x1088 (no detections), 748.3ms
# image 128/268 /kaggle/input/detectionbnmn-3classes/images/test/BN624.png: 832x1088 (no detections), 747.5ms
# image 129/268 /kaggle/input/detectionbnmn-3classes/images/test/BN625.png: 832x1088 (no detections), 759.1ms
# image 130/268 /kaggle/input/detectionbnmn-3classes/images/test/BN626.png: 832x1088 1 MN, 780.1ms
# image 131/268 /kaggle/input/detectionbnmn-3classes/images/test/BN627.png: 832x1088 (no detections), 756.9ms
# image 132/268 /kaggle/input/detectionbnmn-3classes/images/test/BN628.png: 832x1088 (no detections), 748.4ms
# image 133/268 /kaggle/input/detectionbnmn-3classes/images/test/BN637.png: 832x1088 (no detections), 721.9ms
# image 134/268 /kaggle/input/detectionbnmn-3classes/images/test/BN638.png: 832x1088 (no detections), 758.8ms
# image 135/268 /kaggle/input/detectionbnmn-3classes/images/test/BN639.png: 832x1088 (no detections), 764.6ms
# image 136/268 /kaggle/input/detectionbnmn-3classes/images/test/BN640.png: 832x1088 (no detections), 698.4ms
# image 137/268 /kaggle/input/detectionbnmn-3classes/images/test/BN651.png: 832x1088 1 MN, 741.9ms
# image 138/268 /kaggle/input/detectionbnmn-3classes/images/test/BN652.png: 832x1088 (no detections), 755.4ms
# image 139/268 /kaggle/input/detectionbnmn-3classes/images/test/BN653.png: 832x1088 (no detections), 751.3ms
# image 140/268 /kaggle/input/detectionbnmn-3classes/images/test/BN654.png: 832x1088 (no detections), 799.4ms
# image 141/268 /kaggle/input/detectionbnmn-3classes/images/test/BN666.png: 832x1088 (no detections), 854.3ms
# image 142/268 /kaggle/input/detectionbnmn-3classes/images/test/BN667.png: 832x1088 (no detections), 820.7ms
# image 143/268 /kaggle/input/detectionbnmn-3classes/images/test/BN668.png: 832x1088 (no detections), 724.7ms
# image 144/268 /kaggle/input/detectionbnmn-3classes/images/test/BN669.png: 832x1088 (no detections), 760.4ms
# image 145/268 /kaggle/input/detectionbnmn-3classes/images/test/BN681.png: 832x1088 (no detections), 783.7ms
# image 146/268 /kaggle/input/detectionbnmn-3classes/images/test/BN682.png: 832x1088 (no detections), 768.5ms
# image 147/268 /kaggle/input/detectionbnmn-3classes/images/test/BN683.png: 832x1088 (no detections), 784.1ms
# image 148/268 /kaggle/input/detectionbnmn-3classes/images/test/BN684.png: 832x1088 (no detections), 765.4ms
# image 149/268 /kaggle/input/detectionbnmn-3classes/images/test/BN695.png: 832x1088 (no detections), 788.7ms
# image 150/268 /kaggle/input/detectionbnmn-3classes/images/test/BN696.png: 832x1088 (no detections), 772.5ms
# image 151/268 /kaggle/input/detectionbnmn-3classes/images/test/BN697.png: 832x1088 (no detections), 744.8ms
# image 152/268 /kaggle/input/detectionbnmn-3classes/images/test/BN698.png: 832x1088 (no detections), 745.0ms
# image 153/268 /kaggle/input/detectionbnmn-3classes/images/test/BN70.png: 832x1088 (no detections), 742.5ms
# image 154/268 /kaggle/input/detectionbnmn-3classes/images/test/BN709.png: 832x1088 1 MN, 762.5ms
# image 155/268 /kaggle/input/detectionbnmn-3classes/images/test/BN710.png: 832x1088 (no detections), 742.7ms
# image 156/268 /kaggle/input/detectionbnmn-3classes/images/test/BN711.png: 832x1088 (no detections), 780.7ms
# image 157/268 /kaggle/input/detectionbnmn-3classes/images/test/BN712.png: 832x1088 (no detections), 737.2ms
# image 158/268 /kaggle/input/detectionbnmn-3classes/images/test/BN722.png: 832x1088 (no detections), 785.1ms
# image 159/268 /kaggle/input/detectionbnmn-3classes/images/test/BN723.png: 832x1088 (no detections), 752.5ms
# image 160/268 /kaggle/input/detectionbnmn-3classes/images/test/BN724.png: 832x1088 (no detections), 768.0ms
# image 161/268 /kaggle/input/detectionbnmn-3classes/images/test/BN725.png: 832x1088 (no detections), 721.6ms
# image 162/268 /kaggle/input/detectionbnmn-3classes/images/test/BN75.png: 832x1088 (no detections), 778.9ms
# image 163/268 /kaggle/input/detectionbnmn-3classes/images/test/BN76.png: 832x1088 1 MN, 729.9ms
# image 164/268 /kaggle/input/detectionbnmn-3classes/images/test/BN77.png: 832x1088 (no detections), 825.9ms
# image 165/268 /kaggle/input/detectionbnmn-3classes/images/test/BNM
268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN382.png: 832x1088 1 MN, 751.9ms
# image 268/268 /kaggle/input/detectionbnmn-3classes/images/test/BNMN383.png: 832x1088 2 MNs, 753.6ms
# Speed: 10.6ms preprocess, 759.1ms inference, 1.2ms postprocess per image at shape (1, 3, 832, 1088)
# Results saved to runs/detect/predict2
# 121 labels saved to runs/detect/predict2/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 44,  49, 126],
#          [ 47,  49, 123],
#          [ 47,  49, 125],
#          ...,
#          [ 60,  52, 144],
#          [ 68,  49, 145],
#          [ 63,  49, 147]],
#
#         [[ 45,  47, 126],
#          [ 49,  48, 123],
#          [ 49,  49, 125],
#          ...,
#          [ 58,  55, 143],
#          [ 67,  51, 144],
#          [ 64,  51, 144]],
#
#         [[ 44,  48, 124],
#          [ 48,  45, 124],
#          [ 51,  48, 124],
#          ...,
#          [ 59,  55, 142],
#          [ 63,  52, 142],
#          [ 62,  54, 143]],
#
#         ...,
#
#         [[ 51,  54, 129],
#          [ 52,  56, 127],
#          [ 52,  56, 129],
#          ...,
#          [ 64,  66, 159],
#          [ 63,  68, 157],
#          [ 66,  69, 155]],
#
#         [[ 51,  49, 132],
#          [ 51,  52, 129],
#          [ 49,  55, 129],
#          ...,
#          [ 67,  66, 157],
#          [ 71,  67, 153],
#          [ 68,  71, 150]],
#
#         [[ 51,  51, 131],
#          [ 51,  48, 133],
#          [ 48,  51, 132],
#          ...,
#          [ 68,  63, 159],
#          [ 74,  63, 156],
#          [ 68,  67, 155]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN112.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.838010787963867, 'inference': 766.4384841918945, 'postprocess': 0.7753372192382812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 51,  47, 123],
#          [ 51,  45, 125],
#          [ 49,  47, 125],
#          ...,
#          [ 56,  58, 150],
#          [ 56,  58, 150],
#          [ 62,  56, 151]],
#
#         [[ 56,  45, 122],
#          [ 51,  47, 124],
#          [ 48,  48, 125],
#          ...,
#          [ 56,  59, 149],
#          [ 67,  55, 148],
#          [ 69,  54, 148]],
#
#         [[ 49,  48, 123],
#          [ 49,  49, 123],
#          [ 49,  49, 124],
#          ...,
#          [ 58,  58, 151],
#          [ 63,  55, 149],
#          [ 66,  56, 145]],
#
#         ...,
#
#         [[ 49,  32, 148],
#          [ 59,  34, 142],
#          [ 67,  30, 142],
#          ...,
#          [ 66,  63, 160],
#          [ 69,  63, 159],
#          [ 67,  63, 160]],
#
#         [[ 47,  30, 155],
#          [ 55,  32, 148],
#          [ 63,  29, 148],
#          ...,
#          [ 67,  62, 159],
#          [ 71,  63, 158],
#          [ 64,  66, 159]],
#
#         [[ 42,  34, 159],
#          [ 51,  32, 153],
#          [ 60,  29, 150],
#          ...,
#          [ 68,  62, 157],
#          [ 72,  63, 157],
#          [ 63,  66, 159]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN113.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.52568244934082, 'inference': 746.9019889831543, 'postprocess': 0.7383823394775391},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 47,  49, 118],
#          [ 44,  54, 117],
#          [ 42,  56, 118],
#          ...,
#          [ 58,  51, 140],
#          [ 55,  54, 138],
#          [ 58,  52, 137]],
#
#         [[ 48,  45, 119],
#          [ 45,  49, 120],
#          [ 40,  55, 118],
#          ...,
#          [ 56,  54, 139],
#          [ 51,  52, 140],
#          [ 58,  51, 137]],
#
#         [[ 49,  42, 120],
#          [ 45,  47, 122],
#          [ 44,  54, 118],
#          ...,
#          [ 59,  52, 139],
#          [ 56,  52, 138],
#          [ 59,  52, 135]],
#
#         ...,
#
#         [[ 40,  59, 134],
#          [ 45,  58, 133],
#          [ 51,  58, 131],
#          ...,
#          [ 47,   0, 125],
#          [ 42,   0, 124],
#          [ 44,   0, 121]],
#
#         [[ 42,  56, 132],
#          [ 45,  58, 131],
#          [ 48,  59, 129],
#          ...,
#          [ 51,   0, 124],
#          [ 48,   0, 122],
#          [ 48,   0, 120]],
#
#         [[ 42,  58, 131],
#          [ 44,  59, 130],
#          [ 47,  58, 130],
#          ...,
#          [ 55,   0, 122],
#          [ 52,   0, 122],
#          [ 52,   0, 121]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN115.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.715702056884766, 'inference': 760.7369422912598, 'postprocess': 0.7908344268798828},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  45, 138],
#          [ 54,  44, 140],
#          [ 52,  42, 142],
#          ...,
#          [ 63,  52, 152],
#          [ 67,  54, 148],
#          [ 64,  56, 147]],
#
#         [[ 58,  45, 140],
#          [ 56,  44, 142],
#          [ 55,  42, 143],
#          ...,
#          [ 62,  55, 151],
#          [ 67,  54, 149],
#          [ 66,  54, 149]],
#
#         [[ 54,  47, 143],
#          [ 54,  44, 146],
#          [ 52,  47, 144],
#          ...,
#          [ 60,  54, 151],
#          [ 63,  52, 152],
#          [ 62,  55, 151]],
#
#         ...,
#
#         [[ 51,  55, 142],
#          [ 51,  54, 144],
#          [ 52,  54, 142],
#          ...,
#          [ 59,  69, 169],
#          [ 63,  72, 166],
#          [ 64,  74, 166]],
#
#         [[ 47,  56, 144],
#          [ 48,  58, 144],
#          [ 52,  58, 141],
#          ...,
#          [ 62,  71, 166],
#          [ 64,  74, 164],
#          [ 64,  74, 164]],
#
#         [[ 42,  60, 143],
#          [ 47,  59, 144],
#          [ 54,  56, 142],
#          ...,
#          [ 67,  72, 161],
#          [ 67,  72, 163],
#          [ 66,  69, 166]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN116.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.694721221923828, 'inference': 755.3534507751465, 'postprocess': 1.0061264038085938},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  52, 131],
#          [ 49,  51, 136],
#          [ 47,  52, 137],
#          ...,
#          [ 60,  54, 146],
#          [ 58,  55, 148],
#          [ 59,  55, 151]],
#
#         [[ 59,  49, 129],
#          [ 51,  49, 135],
#          [ 44,  52, 135],
#          ...,
#          [ 60,  51, 146],
#          [ 60,  54, 147],
#          [ 60,  52, 150]],
#
#         [[ 56,  51, 128],
#          [ 49,  49, 132],
#          [ 42,  54, 134],
#          ...,
#          [ 58,  54, 145],
#          [ 60,  52, 147],
#          [ 62,  51, 149]],
#
#         ...,
#
#         [[ 47,  58, 140],
#          [ 51,  58, 140],
#          [ 54,  60, 139],
#          ...,
#          [ 64,  69, 164],
#          [ 69,  69, 161],
#          [ 66,  71, 161]],
#
#         [[ 58,  49, 141],
#          [ 56,  55, 138],
#          [ 54,  60, 138],
#          ...,
#          [ 66,  67, 166],
#          [ 72,  68, 162],
#          [ 66,  73, 161]],
#
#         [[ 62,  52, 139],
#          [ 60,  54, 138],
#          [ 55,  58, 139],
#          ...,
#          [ 69,  67, 164],
#          [ 74,  69, 161],
#          [ 66,  74, 161]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN117.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.589765548706055, 'inference': 802.074670791626, 'postprocess': 0.7348060607910156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 52,  59, 113],
#          [ 54,  59, 112],
#          [ 55,  58, 115],
#          ...,
#          [ 66,  62, 143],
#          [ 71,  63, 139],
#          [ 68,  67, 136]],
#
#         [[ 59,  56, 114],
#          [ 58,  58, 113],
#          [ 56,  58, 115],
#          ...,
#          [ 66,  67, 137],
#          [ 72,  64, 137],
#          [ 71,  66, 137]],
#
#         [[ 58,  55, 114],
#          [ 55,  56, 116],
#          [ 54,  59, 115],
#          ...,
#          [ 67,  69, 131],
#          [ 68,  66, 136],
#          [ 67,  64, 139]],
#
#         ...,
#
#         [[ 52,  64, 126],
#          [ 55,  66, 126],
#          [ 59,  63, 126],
#          ...,
#          [ 80,  73, 140],
#          [ 82,  72, 141],
#          [ 77,  73, 144]],
#
#         [[ 60,  60, 126],
#          [ 60,  60, 127],
#          [ 62,  62, 124],
#          ...,
#          [ 79,  74, 139],
#          [ 81,  75, 139],
#          [ 75,  74, 142]],
#
#         [[ 67,  59, 123],
#          [ 66,  58, 123],
#          [ 64,  60, 122],
#          ...,
#          [ 79,  73, 140],
#          [ 82,  72, 140],
#          [ 77,  71, 144]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN136.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.75599479675293, 'inference': 772.9246616363525, 'postprocess': 1.0154247283935547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 58,  52, 122],
#          [ 60,  51, 123],
#          [ 60,  49, 124],
#          ...,
#          [ 72,  56, 146],
#          [ 72,  60, 143],
#          [ 72,  63, 140]],
#
#         [[ 59,  52, 122],
#          [ 58,  52, 122],
#          [ 55,  52, 123],
#          ...,
#          [ 77,  56, 143],
#          [ 77,  59, 140],
#          [ 77,  62, 138]],
#
#         [[ 58,  52, 122],
#          [ 56,  52, 121],
#          [ 52,  56, 120],
#          ...,
#          [ 72,  58, 143],
#          [ 72,  62, 140],
#          [ 72,  64, 137]],
#
#         ...,
#
#         [[ 49,  49, 122],
#          [ 49,  45, 123],
#          [ 49,  44, 125],
#          ...,
#          [ 78,  69, 148],
#          [ 80,  69, 146],
#          [ 79,  72, 144]],
#
#         [[ 47,  48, 124],
#          [ 48,  47, 126],
#          [ 47,  47, 127],
#          ...,
#          [ 83,  69, 146],
#          [ 83,  71, 145],
#          [ 78,  72, 145]],
#
#         [[ 40,  51, 129],
#          [ 42,  49, 129],
#          [ 45,  48, 129],
#          ...,
#          [ 89,  66, 146],
#          [ 87,  68, 145],
#          [ 80,  69, 146]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN137.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.539220809936523, 'inference': 745.7196712493896, 'postprocess': 0.9884834289550781},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 59,  45, 125],
#          [ 59,  45, 125],
#          [ 59,  48, 125],
#          ...,
#          [ 71,  52, 148],
#          [ 77,  54, 142],
#          [ 81,  55, 136]],
#
#         [[ 56,  47, 124],
#          [ 52,  48, 125],
#          [ 49,  51, 125],
#          ...,
#          [ 74,  54, 143],
#          [ 82,  52, 140],
#          [ 83,  51, 138]],
#
#         [[ 60,  47, 123],
#          [ 59,  47, 124],
#          [ 58,  48, 124],
#          ...,
#          [ 75,  55, 140],
#          [ 78,  52, 140],
#          [ 78,  55, 139]],
#
#         ...,
#
#         [[ 66,  45, 137],
#          [ 68,  47, 137],
#          [ 72,  49, 135],
#          ...,
#          [ 75,  62, 163],
#          [ 75,  63, 160],
#          [ 75,  63, 158]],
#
#         [[ 66,  45, 137],
#          [ 67,  49, 134],
#          [ 67,  52, 134],
#          ...,
#          [ 80,  63, 160],
#          [ 81,  64, 159],
#          [ 78,  63, 158]],
#
#         [[ 66,  49, 133],
#          [ 66,  49, 133],
#          [ 64,  51, 134],
#          ...,
#          [ 87,  59, 159],
#          [ 88,  62, 158],
#          [ 81,  60, 161]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN143.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.492013931274414, 'inference': 801.8832206726074, 'postprocess': 1.0116100311279297},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  45, 119],
#          [ 67,  42, 119],
#          [ 69,  44, 118],
#          ...,
#          [ 77,  62, 150],
#          [ 79,  62, 150],
#          [ 79,  60, 152]],
#
#         [[ 63,  42, 119],
#          [ 62,  42, 119],
#          [ 56,  47, 120],
#          ...,
#          [ 78,  64, 150],
#          [ 82,  63, 149],
#          [ 79,  62, 152]],
#
#         [[ 67,  40, 118],
#          [ 67,  42, 116],
#          [ 64,  47, 116],
#          ...,
#          [ 74,  66, 150],
#          [ 75,  64, 152],
#          [ 75,  63, 153]],
#
#         ...,
#
#         [[ 60,  59, 129],
#          [ 67,  58, 127],
#          [ 72,  56, 126],
#          ...,
#          [ 82,  75, 168],
#          [ 80,  79, 167],
#          [ 86,  77, 166]],
#
#         [[ 66,  56, 129],
#          [ 72,  56, 124],
#          [ 75,  54, 125],
#          ...,
#          [ 86,  78, 163],
#          [ 82,  81, 163],
#          [ 85,  78, 166]],
#
#         [[ 71,  54, 128],
#          [ 74,  54, 125],
#          [ 75,  52, 127],
#          ...,
#          [ 88,  74, 164],
#          [ 87,  78, 164],
#          [ 87,  77, 166]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN145.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.347532272338867, 'inference': 763.5741233825684, 'postprocess': 1.0247230529785156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  32, 136],
#          [ 66,  27, 134],
#          [ 68,  30, 126],
#          ...,
#          [ 75,  63, 154],
#          [ 79,  62, 151],
#          [ 83,  62, 146]],
#
#         [[ 63,  36, 135],
#          [ 62,  36, 134],
#          [ 60,  36, 129],
#          ...,
#          [ 81,  64, 149],
#          [ 83,  60, 149],
#          [ 87,  59, 148]],
#
#         [[ 58,  39, 136],
#          [ 58,  37, 136],
#          [ 58,  40, 133],
#          ...,
#          [ 77,  67, 148],
#          [ 74,  64, 150],
#          [ 80,  60, 152]],
#
#         ...,
#
#         [[ 32,   0,  87],
#          [ 32,   0,  82],
#          [ 32,   0,  81],
#          ...,
#          [ 83,  59, 159],
#          [ 83,  56, 152],
#          [ 90,  51, 145]],
#
#         [[ 36,   0,  89],
#          [ 36,   0,  86],
#          [ 32,   0,  80],
#          ...,
#          [ 88,  58, 155],
#          [ 89,  56, 148],
#          [ 88,  54, 142]],
#
#         [[ 37,   0,  93],
#          [ 36,   0,  87],
#          [ 30,   0,  82],
#          ...,
#          [ 92,  58, 149],
#          [ 97,  54, 145],
#          [ 86,  54, 143]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN152.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.023521423339844, 'inference': 778.1915664672852, 'postprocess': 1.4433860778808594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 75,  45,  97],
#          [ 74,  47,  99],
#          [ 73,  48, 101],
#          ...,
#          [ 63,  64, 155],
#          [ 67,  66, 151],
#          [ 74,  66, 146]],
#
#         [[ 77,  44, 102],
#          [ 71,  47, 106],
#          [ 66,  48, 110],
#          ...,
#          [ 66,  69, 149],
#          [ 73,  64, 150],
#          [ 79,  60, 149]],
#
#         [[ 72,  45, 109],
#          [ 67,  47, 113],
#          [ 60,  49, 117],
#          ...,
#          [ 71,  69, 145],
#          [ 74,  62, 149],
#          [ 75,  59, 153]],
#
#         ...,
#
#         [[ 56,  62, 132],
#          [ 62,  62, 131],
#          [ 66,  62, 129],
#          ...,
#          [ 74,  73, 161],
#          [ 68,  75, 163],
#          [ 73,  74, 161]],
#
#         [[ 64,  58, 132],
#          [ 64,  59, 131],
#          [ 64,  62, 130],
#          ...,
#          [ 74,  75, 161],
#          [ 73,  77, 161],
#          [ 73,  75, 163]],
#
#         [[ 73,  56, 128],
#          [ 68,  59, 129],
#          [ 63,  60, 130],
#          ...,
#          [ 74,  75, 165],
#          [ 79,  75, 163],
#          [ 75,  75, 163]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN200.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.37399673461914, 'inference': 828.5822868347168, 'postprocess': 1.0628700256347656},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  39, 113],
#          [ 60,  40, 114],
#          [ 56,  42, 115],
#          ...,
#          [ 72,  54, 138],
#          [ 74,  52, 135],
#          [ 77,  54, 130]],
#
#         [[ 67,  37, 111],
#          [ 64,  39, 112],
#          [ 60,  42, 113],
#          ...,
#          [ 67,  54, 138],
#          [ 75,  51, 133],
#          [ 77,  51, 130]],
#
#         [[ 63,  40, 110],
#          [ 62,  44, 110],
#          [ 58,  47, 110],
#          ...,
#          [ 67,  56, 135],
#          [ 71,  52, 132],
#          [ 74,  55, 128]],
#
#         ...,
#
#         [[ 55,  58, 124],
#          [ 60,  58, 120],
#          [ 66,  58, 118],
#          ...,
#          [ 39,   0,  77],
#          [ 39,   0,  78],
#          [ 39,   0,  78]],
#
#         [[ 58,  54, 123],
#          [ 60,  58, 118],
#          [ 62,  58, 117],
#          ...,
#          [ 44,   0,  74],
#          [ 45,   0,  73],
#          [ 44,   0,  73]],
#
#         [[ 58,  52, 123],
#          [ 58,  52, 122],
#          [ 58,  52, 121],
#          ...,
#          [ 47,   0,  75],
#          [ 51,   0,  72],
#          [ 48,   0,  72]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN201.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.380910873413086, 'inference': 757.7300071716309, 'postprocess': 0.8835792541503906},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 66,  55, 121],
#          [ 66,  59, 119],
#          [ 63,  59, 125],
#          ...,
#          [ 72,  52, 129],
#          [ 69,  51, 129],
#          [ 69,  54, 128]],
#
#         [[ 69,  45, 127],
#          [ 64,  51, 126],
#          [ 58,  55, 129],
#          ...,
#          [ 78,  54, 122],
#          [ 79,  49, 123],
#          [ 77,  49, 125]],
#
#         [[ 51,  32, 137],
#          [ 48,  37, 138],
#          [ 45,  45, 136],
#          ...,
#          [ 78,  56, 115],
#          [ 79,  52, 119],
#          [ 78,  48, 124]],
#
#         ...,
#
#         [[ 48,  64, 141],
#          [ 56,  62, 142],
#          [ 66,  60, 140],
#          ...,
#          [ 85,  58, 143],
#          [ 82,  60, 138],
#          [ 81,  62, 133]],
#
#         [[ 49,  64, 143],
#          [ 58,  60, 146],
#          [ 66,  60, 145],
#          ...,
#          [ 85,  56, 146],
#          [ 87,  59, 135],
#          [ 82,  64, 127]],
#
#         [[ 55,  66, 141],
#          [ 62,  63, 141],
#          [ 68,  64, 140],
#          ...,
#          [ 87,  58, 144],
#          [ 91,  58, 134],
#          [ 83,  62, 128]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BN202.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.434555053710938, 'inference': 728.9490699768066, 'postprocess': 1.0404586791992188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  47, 109],
#          [ 55,  47, 112],
#          [ 55,  48, 113],
#          ...,
#          [ 58,  52, 152],
#          [ 66,  55, 146],
# ...
#
#         ...,
#
#         [[ 42,  62, 129],
#          [ 45,  60, 129],
#          [ 51,  59, 129],
#          ...,
#          [ 54,  68, 137],
#          [ 56,  67, 134],
#          [ 60,  64, 133]],
#
#         [[ 47,  59, 129],
#          [ 47,  56, 132],
#          [ 49,  58, 130],
#          ...,
#          [ 54,  66, 138],
#          [ 56,  67, 135],
#          [ 55,  67, 132]],
#
#         [[ 52,  56, 128],
#          [ 51,  56, 129],
#          [ 49,  56, 129],
#          ...,
#          [ 55,  64, 139],
#          [ 55,  68, 134],
#          [ 49,  68, 134]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN360.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.595010757446289, 'inference': 747.2193241119385, 'postprocess': 1.435995101928711},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 45,  51, 128],
#          [ 48,  47, 130],
#          [ 51,  48, 129],
#          ...,
#          [ 47,  49, 138],
#          [ 54,  51, 135],
#          [ 54,  52, 135]],
#
#         [[ 54,  49, 125],
#          [ 55,  48, 126],
#          [ 55,  48, 126],
#          ...,
#          [ 44,  49, 137],
#          [ 54,  51, 134],
#          [ 55,  51, 134]],
#
#         [[ 48,  51, 125],
#          [ 51,  51, 124],
#          [ 52,  51, 126],
#          ...,
#          [ 40,  51, 136],
#          [ 52,  51, 135],
#          [ 52,  49, 135]],
#
#         ...,
#
#         [[ 39,  59, 128],
#          [ 42,  59, 127],
#          [ 44,  58, 129],
#          ...,
#          [ 40,  58, 136],
#          [ 45,  56, 135],
#          [ 51,  52, 135]],
#
#         [[ 47,  56, 128],
#          [ 47,  59, 125],
#          [ 44,  60, 127],
#          ...,
#          [ 47,  56, 133],
#          [ 48,  56, 134],
#          [ 49,  54, 135]],
#
#         [[ 51,  58, 126],
#          [ 49,  58, 125],
#          [ 47,  58, 125],
#          ...,
#          [ 52,  55, 132],
#          [ 49,  58, 132],
#          [ 48,  58, 133]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN366.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.748075485229492, 'inference': 748.8596439361572, 'postprocess': 1.420736312866211},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 48,  64, 140],
#          [ 51,  63, 139],
#          [ 52,  62, 140],
#          ...,
#          [ 52,  59, 152],
#          [ 48,  64, 151],
#          [ 54,  67, 148]],
#
#         [[ 49,  63, 139],
#          [ 47,  64, 139],
#          [ 42,  66, 140],
#          ...,
#          [ 51,  62, 149],
#          [ 51,  63, 149],
#          [ 58,  63, 148]],
#
#         [[ 48,  66, 137],
#          [ 42,  67, 140],
#          [ 39,  68, 140],
#          ...,
#          [ 48,  67, 148],
#          [ 48,  64, 150],
#          [ 54,  60, 153]],
#
#         ...,
#
#         [[ 48,  62, 141],
#          [ 48,  60, 143],
#          [ 51,  59, 143],
#          ...,
#          [ 52,  67, 146],
#          [ 47,  67, 146],
#          [ 48,  68, 146]],
#
#         [[ 44,  62, 142],
#          [ 45,  62, 141],
#          [ 49,  60, 141],
#          ...,
#          [ 49,  63, 148],
#          [ 51,  64, 147],
#          [ 48,  66, 148]],
#
#         [[ 36,  66, 142],
#          [ 40,  66, 141],
#          [ 47,  63, 141],
#          ...,
#          [ 49,  63, 148],
#          [ 56,  62, 147],
#          [ 47,  64, 147]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN367.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.779069900512695, 'inference': 754.8041343688965, 'postprocess': 1.3234615325927734},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 48,  59, 130],
#          [ 45,  59, 130],
#          [ 40,  59, 132],
#          ...,
#          [ 49,  60, 142],
#          [ 55,  59, 138],
#          [ 56,  58, 136]],
#
#         [[ 51,  56, 129],
#          [ 48,  56, 130],
#          [ 44,  59, 131],
#          ...,
#          [ 58,  60, 137],
#          [ 60,  56, 137],
#          [ 59,  55, 136]],
#
#         [[ 52,  56, 129],
#          [ 49,  59, 129],
#          [ 45,  62, 129],
#          ...,
#          [ 52,  63, 134],
#          [ 55,  59, 135],
#          [ 55,  59, 135]],
#
#         ...,
#
#         [[ 27,  66, 133],
#          [ 39,  66, 130],
#          [ 52,  64, 126],
#          ...,
#          [ 51,  64, 139],
#          [ 54,  64, 136],
#          [ 51,  66, 134]],
#
#         [[ 34,  63, 132],
#          [ 44,  62, 131],
#          [ 54,  60, 129],
#          ...,
#          [ 48,  64, 140],
#          [ 48,  68, 137],
#          [ 49,  66, 136]],
#
#         [[ 37,  60, 133],
#          [ 47,  59, 131],
#          [ 56,  56, 129],
#          ...,
#          [ 48,  67, 135],
#          [ 47,  67, 135],
#          [ 49,  66, 134]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN368.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 13.885974884033203, 'inference': 733.0367565155029, 'postprocess': 1.3904571533203125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  55, 116],
#          [ 59,  58, 116],
#          [ 58,  58, 115],
#          ...,
#          [ 60,  63, 123],
#          [ 59,  60, 125],
#          [ 58,  60, 127]],
#
#         [[ 56,  58, 116],
#          [ 54,  59, 117],
#          [ 54,  60, 116],
#          ...,
#          [ 59,  60, 127],
#          [ 59,  58, 128],
#          [ 59,  56, 129]],
#
#         [[ 52,  58, 117],
#          [ 52,  59, 119],
#          [ 54,  60, 116],
#          ...,
#          [ 54,  60, 129],
#          [ 54,  59, 130],
#          [ 58,  59, 129]],
#
#         ...,
#
#         [[ 51,  59, 121],
#          [ 55,  60, 119],
#          [ 60,  62, 116],
#          ...,
#          [ 56,  40, 119],
#          [ 54,  40, 121],
#          [ 56,  42, 122]],
#
#         [[ 47,  60, 123],
#          [ 51,  59, 123],
#          [ 58,  58, 120],
#          ...,
#          [ 56,  39, 119],
#          [ 54,  40, 120],
#          [ 52,  44, 121]],
#
#         [[ 48,  60, 120],
#          [ 52,  59, 120],
#          [ 56,  59, 117],
#          ...,
#          [ 58,  39, 114],
#          [ 54,  42, 118],
#          [ 49,  45, 121]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN369.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.200904846191406, 'inference': 724.9391078948975, 'postprocess': 1.2254714965820312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 52,  59, 118],
#          [ 56,  56, 119],
#          [ 58,  58, 118],
#          ...,
#          [ 56,  54, 123],
#          [ 54,  54, 126],
#          [ 56,  58, 125]],
#
#         [[ 62,  56, 117],
#          [ 59,  58, 117],
#          [ 56,  59, 116],
#          ...,
#          [ 59,  54, 122],
#          [ 54,  54, 125],
#          [ 56,  59, 125]],
#
#         [[ 55,  60, 117],
#          [ 56,  60, 117],
#          [ 58,  60, 116],
#          ...,
#          [ 59,  58, 119],
#          [ 52,  60, 123],
#          [ 52,  64, 124]],
#
#         ...,
#
#         [[ 51,  60, 117],
#          [ 58,  60, 114],
#          [ 63,  59, 116],
#          ...,
#          [ 49,  67, 120],
#          [ 48,  68, 118],
#          [ 54,  67, 115]],
#
#         [[ 55,  56, 119],
#          [ 55,  58, 118],
#          [ 56,  60, 118],
#          ...,
#          [ 54,  66, 118],
#          [ 52,  67, 116],
#          [ 56,  64, 113]],
#
#         [[ 55,  59, 117],
#          [ 54,  60, 115],
#          [ 51,  62, 116],
#          ...,
#          [ 58,  63, 120],
#          [ 59,  62, 118],
#          [ 58,  60, 117]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN374.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.953643798828125, 'inference': 708.228588104248, 'postprocess': 1.5003681182861328},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  62, 122],
#          [ 64,  62, 121],
#          [ 67,  60, 121],
#          ...,
#          [ 56,  69, 129],
#          [ 63,  69, 126],
#          [ 64,  68, 126]],
#
#         [[ 63,  60, 123],
#          [ 60,  62, 123],
#          [ 58,  62, 123],
#          ...,
#          [ 55,  72, 129],
#          [ 69,  67, 127],
#          [ 68,  66, 127]],
#
#         [[ 55,  64, 123],
#          [ 55,  62, 127],
#          [ 55,  62, 127],
#          ...,
#          [ 55,  71, 128],
#          [ 59,  67, 129],
#          [ 59,  66, 131]],
#
#         ...,
#
#         [[ 52,  63, 122],
#          [ 56,  64, 122],
#          [ 62,  64, 119],
#          ...,
#          [ 52,  71, 129],
#          [ 49,  72, 129],
#          [ 56,  69, 128]],
#
#         [[ 55,  62, 124],
#          [ 56,  63, 124],
#          [ 58,  64, 121],
#          ...,
#          [ 55,  69, 129],
#          [ 54,  72, 128],
#          [ 55,  71, 127]],
#
#         [[ 56,  63, 122],
#          [ 55,  63, 124],
#          [ 55,  66, 121],
#          ...,
#          [ 59,  68, 129],
#          [ 60,  69, 127],
#          [ 55,  69, 127]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN375.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.044979095458984, 'inference': 754.4727325439453, 'postprocess': 1.5439987182617188},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 62,  64, 128],
#          [ 60,  64, 127],
#          [ 58,  66, 127],
#          ...,
#          [ 64,  72, 133],
#          [ 64,  71, 132],
#          [ 68,  69, 130]],
#
#         [[ 60,  62, 129],
#          [ 59,  63, 129],
#          [ 56,  66, 129],
#          ...,
#          [ 67,  69, 133],
#          [ 72,  68, 131],
#          [ 69,  67, 133]],
#
#         [[ 60,  62, 129],
#          [ 58,  62, 131],
#          [ 55,  66, 131],
#          ...,
#          [ 63,  72, 134],
#          [ 67,  69, 133],
#          [ 67,  68, 135]],
#
#         ...,
#
#         [[ 56,  66, 124],
#          [ 59,  68, 124],
#          [ 59,  71, 122],
#          ...,
#          [ 64,  68, 132],
#          [ 62,  71, 133],
#          [ 59,  72, 134]],
#
#         [[ 59,  63, 126],
#          [ 59,  67, 122],
#          [ 58,  71, 123],
#          ...,
#          [ 66,  69, 131],
#          [ 64,  71, 133],
#          [ 56,  72, 136]],
#
#         [[ 55,  64, 128],
#          [ 56,  66, 126],
#          [ 56,  67, 125],
#          ...,
#          [ 64,  69, 133],
#          [ 67,  69, 133],
#          [ 55,  73, 135]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN376.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 7.933616638183594, 'inference': 737.0984554290771, 'postprocess': 1.146078109741211},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 54,  59, 119],
#          [ 49,  63, 118],
#          [ 48,  63, 118],
#          ...,
#          [ 54,  63, 134],
#          [ 58,  64, 129],
#          [ 59,  68, 123]],
#
#         [[ 59,  59, 118],
#          [ 54,  60, 119],
#          [ 51,  62, 119],
#          ...,
#          [ 58,  67, 127],
#          [ 62,  66, 126],
#          [ 60,  67, 125]],
#
#         [[ 55,  60, 118],
#          [ 52,  60, 120],
#          [ 51,  60, 120],
#          ...,
#          [ 59,  69, 122],
#          [ 59,  68, 123],
#          [ 59,  66, 126]],
#
#         ...,
#
#         [[ 47,  66, 116],
#          [ 54,  64, 115],
#          [ 63,  63, 112],
#          ...,
#          [ 51,  72, 126],
#          [ 48,  72, 126],
#          [ 51,  71, 126]],
#
#         [[ 45,  64, 117],
#          [ 52,  63, 116],
#          [ 58,  62, 113],
#          ...,
#          [ 55,  71, 125],
#          [ 55,  72, 124],
#          [ 54,  69, 124]],
#
#         [[ 42,  66, 117],
#          [ 47,  60, 119],
#          [ 51,  62, 116],
#          ...,
#          [ 60,  68, 125],
#          [ 64,  68, 123],
#          [ 58,  67, 124]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN377.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 8.263826370239258, 'inference': 737.2548580169678, 'postprocess': 1.4121532440185547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 56,  62, 131],
#          [ 55,  62, 130],
#          [ 54,  63, 130],
#          ...,
#          [ 56,  67, 141],
#          [ 58,  68, 137],
#          [ 63,  71, 131]],
#
#         [[ 60,  62, 129],
#          [ 56,  60, 131],
#          [ 54,  62, 130],
#          ...,
#          [ 55,  71, 139],
#          [ 55,  69, 138],
#          [ 63,  68, 136]],
#
#         [[ 54,  63, 129],
#          [ 54,  63, 130],
#          [ 54,  63, 129],
#          ...,
#          [ 51,  75, 136],
#          [ 51,  73, 138],
#          [ 56,  69, 140]],
#
#         ...,
#
#         [[ 36,  68, 132],
#          [ 44,  69, 129],
#          [ 52,  67, 128],
#          ...,
#          [ 45,  68, 139],
#          [ 47,  68, 139],
#          [ 56,  66, 137]],
#
#         [[ 44,  66, 131],
#          [ 49,  67, 128],
#          [ 54,  67, 127],
#          ...,
#          [ 52,  67, 136],
#          [ 51,  68, 137],
#          [ 56,  66, 138]],
#
#         [[ 51,  66, 128],
#          [ 54,  64, 127],
#          [ 54,  67, 126],
#          ...,
#          [ 59,  64, 133],
#          [ 58,  66, 135],
#          [ 56,  64, 136]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN382.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.71112060546875, 'inference': 751.8649101257324, 'postprocess': 1.4140605926513672},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BN', 1: 'BNMN', 2: 'MN'}
#  obb: None
#  orig_img: array([[[ 51,  58, 122],
#          [ 51,  60, 120],
#          [ 52,  60, 119],
#          ...,
#          [ 52,  62, 128],
#          [ 55,  64, 123],
#          [ 58,  67, 117]],
#
#         [[ 48,  58, 122],
#          [ 49,  59, 122],
#          [ 51,  59, 121],
#          ...,
#          [ 55,  63, 126],
#          [ 58,  63, 124],
#          [ 60,  62, 122]],
#
#         [[ 49,  60, 120],
#          [ 48,  59, 123],
#          [ 49,  60, 121],
#          ...,
#          [ 54,  66, 124],
#          [ 54,  62, 127],
#          [ 56,  59, 129]],
#
#         ...,
#
#         [[ 45,  59, 118],
#          [ 48,  59, 119],
#          [ 54,  58, 118],
#          ...,
#          [ 47,  63, 129],
#          [ 42,  66, 128],
#          [ 45,  64, 126]],
#
#         [[ 49,  58, 118],
#          [ 51,  58, 118],
#          [ 54,  58, 118],
#          ...,
#          [ 51,  60, 129],
#          [ 49,  64, 126],
#          [ 49,  66, 123]],
#
#         [[ 52,  58, 116],
#          [ 54,  56, 117],
#          [ 55,  58, 116],
#          ...,
#          [ 58,  59, 127],
#          [ 59,  60, 125],
#          [ 55,  63, 124]]], dtype=uint8)
#  orig_shape: (1536, 2048)
#  path: '/kaggle/input/detectionbnmn-3classes/images/test/BNMN383.png'
#  probs: None
#  save_dir: 'runs/detect/predict2'
#  speed: {'preprocess': 11.371135711669922, 'inference': 753.6036968231201, 'postprocess': 1.3976097106933594}]

# %% [markdown]
# ### 4. Remove as classes desejadas do resultados do modelo de 3 classes, a fim de realizar a junção como modelo de 1 classe

# %%
input_dir = '/kaggle/input/predicts-ensemble/predictBN11l/kaggle/working/runs/detect/predict/labels'
output_dir = '/kaggle/working/rmv_predict_11l'

class_id_to_remove = '2'

os.makedirs(output_dir, exist_ok=True)

for filename in os.listdir(input_dir):
    if filename.endswith('.txt'):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        with open(input_path, 'r') as file:
            lines = file.readlines()

        new_lines = [line for line in lines if not line.startswith(class_id_to_remove)]

        with open(output_path, 'w') as file:
            file.writelines(new_lines)

print("Anotações da classe MN removidas e salvas no novo diretório com sucesso.")
# Out:
# Anotações da classe MN removidas e salvas no novo diretório com sucesso.

# %% [markdown]
# ### 5. Realiza a junção dos resultados do modelo de 3 classes com a classe removida e o modelo de 1 classe

# %%
input_dir1 = '/kaggle/working/rmv_predict_11l'
input_dir2 = '/kaggle/input/predicts-ensemble/predictMN11s/kaggle/working/runs/detect/predict2/labels'

output_dir = '/kaggle/working/final_predict_ensemble'

os.makedirs(output_dir, exist_ok=True)

for filename in os.listdir(input_dir1):
    if filename.endswith('.txt'):
        input_path1 = os.path.join(input_dir1, filename)
        input_path2 = os.path.join(input_dir2, filename)
        output_path = os.path.join(output_dir, filename)

        with open(input_path1, 'r') as file1:
            dir1 = file1.readlines()

        if os.path.exists(input_path2):
            with open(input_path2, 'r') as file2:
                dir2 = file2.readlines()
        else: 
            dir2 = []

        final_dir = dir1 + dir2

        with open(output_path, 'w') as f_out:
            f_out.writelines(final_dir)

print("Processo concluído")
# Out:
# Processo concluído

# %% [markdown]
# ### 6. Funções de auxílio para a visualização dos resultados

# %%
from scipy.optimize import linear_sum_assignment

#Calcula o IOU dos resultados
def get_iou(ground_truth, pred):
    ix1 = np.maximum(ground_truth[0], pred[0])
    iy1 = np.maximum(ground_truth[1], pred[1])
    ix2 = np.minimum(ground_truth[2], pred[2])
    iy2 = np.minimum(ground_truth[3], pred[3])
     
    i_height = np.maximum(iy2 - iy1 + 1, np.array(0.))
    i_width = np.maximum(ix2 - ix1 + 1, np.array(0.))
     
    area_of_intersection = i_height * i_width
     
    gt_height = ground_truth[3] - ground_truth[1] + 1
    gt_width = ground_truth[2] - ground_truth[0] + 1
     
    pd_height = pred[3] - pred[1] + 1
    pd_width = pred[2] - pred[0] + 1
     
    area_of_union = gt_height * gt_width + pd_height * pd_width - area_of_intersection
     
    iou = area_of_intersection / area_of_union
     
    return iou

#Desenha as bboxes preditas
def draw_bounding_boxes(image, gt_box, pred_box, iou, threshold=0.5, class_correct=True, false_positive=False):
    label = f"IoU: {iou:.2f}"
    
    if false_positive:
        color = (0, 0, 255)
        label = "Detecção incorreta"
        
    elif class_correct and iou >= threshold:
        color = (0, 255, 0)  # Verde
    elif class_correct and iou == 0:
        color = (255, 0, 0)  # Azul
    elif class_correct and iou < threshold:
        color = (0, 255, 255)  # Amarelo
        
    elif class_correct == False:
        color = (0, 0, 255)
        label = "classe incorreta"

    if gt_box is not None:
        cv2.rectangle(image, (int(gt_box[0]), int(gt_box[1])), (int(gt_box[2]), int(gt_box[3])), color, 2)
        cv2.putText(image, label, (int(gt_box[0]), int(gt_box[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

    if gt_box is None and pred_box is not None:
        cv2.rectangle(image, (int(pred_box[0]), int(pred_box[1])), (int(pred_box[2]), int(pred_box[3])), color, 2)
        cv2.putText(image, label, (int(pred_box[0]), int(pred_box[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

    return image

#Carrega o ground truth para comparação
def load_ground_truth(label_path, image):
    boxes = []
    classes = []
    height, width, _ = image.shape
    with open(label_path, "r") as f:
        for line in f:
            class_id, center_x, center_y, bbox_width, bbox_height = map(float, line.strip().split())
            x1 = int((center_x - bbox_width / 2) * width)
            y1 = int((center_y - bbox_height / 2) * height)
            x2 = int((center_x + bbox_width / 2) * width)
            y2 = int((center_y + bbox_height / 2) * height)
            boxes.append([x1, y1, x2, y2])
            classes.append(int(class_id))
            
    return boxes, classes

#Faz a comparação do ground truth com as predições
def match_predictions_with_gt(gt_boxes, pred_boxes):
    num_gt = len(gt_boxes)
    num_pred = len(pred_boxes)
    
    iou_matrix = np.zeros((num_gt, num_pred))

    for i, gt in enumerate(gt_boxes):
        for j, pred in enumerate(pred_boxes):
            iou_matrix[i, j] = get_iou(gt, pred)
    
    # Resolver o problema de associação com Hungarian Algorithm
    gt_indices, pred_indices = linear_sum_assignment(-iou_matrix)  # Negativo porque queremos maximizar IoU
    
    # Identificar correspondências válidas
    matches = []
    unmatched_gt = set(range(num_gt))  # Ground truths sem correspondência
    unmatched_pred = set(range(num_pred))  # Predições sem correspondência

    for gt_idx, pred_idx in zip(gt_indices, pred_indices):
        iou = iou_matrix[gt_idx, pred_idx]
        if iou > 0:  # Apenas associações válidas
            matches.append((gt_idx, pred_idx, iou))
            unmatched_gt.discard(gt_idx)
            unmatched_pred.discard(pred_idx)

    # Adicionar GTs sem correspondência com IoU = 0
    for gt_idx in unmatched_gt:
        matches.append((gt_idx, None, 0.0))

    # Adicionar previsões sem correspondência como falsos positivos
    for pred_idx in unmatched_pred:
        matches.append((None, pred_idx, 0.0))

    return matches

# %% [markdown]
# ### 7. Realiza o pós-processamento para identificação incorreta de células com micronúcleo

# %%
def save_YOLO_labels(output_path, boxes, classes, image):
    height, width, _ = image.shape
    with open(output_path, "w") as f:
        for box, class_id in zip(boxes, classes):
            center_x = ((box[0] + box[2]) / 2) / width
            center_y = ((box[1] + box[3]) / 2) / height
            bbox_width = (box[2] - box[0]) / width
            bbox_height = (box[3] - box[1]) / height
            f.write(f"{class_id} {center_x:.6f} {center_y:.6f} {bbox_width:.6f} {bbox_height:.6f}\n")


def adjust_classes_based_on_micronuclei(pred_boxes, pred_classes):
    adjusted_classes = pred_classes.copy()
    micronuclei_indices = [i for i, c in enumerate(pred_classes) if c == 2]
    
    cell_indices = [i for i, c in enumerate(pred_classes) if c == 0]

    for cell_idx in cell_indices:
        cell_box = pred_boxes[cell_idx]
        for mn_idx in micronuclei_indices:
            mn_box = pred_boxes[mn_idx]
            iou = get_iou(cell_box, mn_box)
 
            if iou > 0:
                adjusted_classes[cell_idx] = 1
                print(f"Célula {cell_idx} ajustada para classe 1 devido ao micronúcleo {mn_idx} (IoU: {iou:.2f})")
                break
    return adjusted_classes

pred_dir = "/kaggle/input/predicts-ensemble/predict_ensemble/kaggle/working/final_predict_ensemble"
gt_dir = "/kaggle/input/detectionbnmn-3classes/labels/test"
output_dir = "/kaggle/working/post_process"
img_dir = "/kaggle/input/detectionbnmn-3classes/images/test"

image_paths = [os.path.join(img_dir, f) for f in os.listdir(img_dir)]
os.makedirs(output_dir, exist_ok=True)


for img in image_paths:
    image = cv2.imread(img)
    image_name = os.path.basename(img)
    
    label_pred_path = os.path.join(pred_dir, os.path.splitext(image_name)[0] + ".txt")
    label_output_path = os.path.join(output_dir, os.path.splitext(image_name)[0] + ".txt")

    if not os.path.exists(label_pred_path):
        print(f"Predição não encontrada para {image_name}. Pulando...")
        continue

    pred_boxes, pred_classes = load_ground_truth(label_pred_path, image)

    adjusted_classes = adjust_classes_based_on_micronuclei(pred_boxes, pred_classes)

    save_YOLO_labels(label_output_path, pred_boxes, adjusted_classes, image)
    print(f"Labels ajustados salvos em: {label_output_path}")
# Out:
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN172.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN379.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN53.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN561.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN682.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN584.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN301.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN260.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN147.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN557.txt
# Célula 1 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.03)
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN293.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN201.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN333.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN272.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN113.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN261.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN509.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN184.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN193.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN418.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN366.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN276.txt
# Célula 1 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.01)
# Labels ajustados salvos em: /kaggle/working/post_process/BN610.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN229.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN475.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN724.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN279.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN640.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN533.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN349.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN697.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN152.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN220.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN149.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN668.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN666.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN171.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN442.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN164.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN347.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN155.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN709.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN244.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN531.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN368.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN253.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN168.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN270.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN507.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN470.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.01)
# Labels ajustados salvos em: /kaggle/working/post_process/BN331.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN192.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.04)
# Labels ajustados salvos em: /kaggle/working/post_process/BN306.txt
# Célula 1 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN226.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN360.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN274.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN536.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN294.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN202.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN205.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN711.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN302.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN441.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN208.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN381.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN336.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN556.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN304.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN206.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN325.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN628.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN624.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN586.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN269.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.04)
# Labels ajustados salvos em: /kaggle/working/post_process/BN227.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN558.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN443.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN224.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN250.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN275.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN318.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN207.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN265.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN201.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN474.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN183.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN419.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN143.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN562.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN346.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN374.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.03)
# Labels ajustados salvos em: /kaggle/working/post_process/BN585.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN148.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN243.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN695.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN420.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN351.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN153.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN712.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN150.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN473.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN389.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN179.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN416.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN191.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN588.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN194.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN136.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN607.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN383.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN232.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN447.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN329.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN698.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN376.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN608.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN653.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN167.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN317.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN375.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN303.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN157.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN352.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN440.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN413.txt
# Célula 1 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN54.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN115.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN56.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN504.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN696.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN383.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN415.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN202.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN204.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN587.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN156.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN302.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN472.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN477.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN281.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN414.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN652.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN310.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN722.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN178.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN535.txt
# Célula 1 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.07)
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN158.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN234.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN681.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN448.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN446.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN181.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN378.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN376.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.04)
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN195.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN309.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN351.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN439.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN70.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN332.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.01)
# Labels ajustados salvos em: /kaggle/working/post_process/BN626.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN667.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN207.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN163.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN476.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN352.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN375.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN198.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN237.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN199.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN188.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN248.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN589.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN468.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN186.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN145.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN166.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN154.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN112.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN627.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN160.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN334.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN532.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN190.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN654.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN613.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN710.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN268.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN326.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN684.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN169.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN469.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN152.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN182.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN271.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN175.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN554.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN380.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN173.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN257.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 2 (IoU: 0.02)
# Labels ajustados salvos em: /kaggle/working/post_process/BN500.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN367.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN382.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN669.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN502.txt
# Célula 0 ajustada para classe 1 devido ao micronúcleo 1 (IoU: 0.01)
# Labels ajustados salvos em: /kaggle/working/post_process/BN76.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN637.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN444.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN165.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN75.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN638.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN501.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN200.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN683.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN506.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN159.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN534.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN417.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN353.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN307.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN176.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN373.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN639.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN651.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN385.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN343.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN508.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN137.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN343.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN377.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN177.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN185.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN162.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN77.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN382.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN269.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN583.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN151.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN344.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN369.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN187.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN280.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN612.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN278.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN117.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN161.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN555.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN374.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN270.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN359.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN337.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN723.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN196.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN623.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN330.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN377.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN384.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN116.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN311.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN305.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN611.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN254.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN174.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN560.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN559.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN725.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BNMN197.txt
# Labels ajustados salvos em: /kaggle/working/post_process/BN625.txt

# %%
image_dir = "/kaggle/input/detectionbnmn-3classes/images/test"  
label_dir = "/kaggle/input/detectionbnmn-3classes/labels/test"
output_dir = "/kaggle/working/out_post_process"

image_paths = [os.path.join(image_dir, f) for f in os.listdir(image_dir)]
os.makedirs(output_dir, exist_ok=True)

for img in image_paths:
    image = cv2.imread(img)
    image_name = os.path.basename(img)

    label_path = os.path.join(label_dir, os.path.splitext(image_name)[0] + ".txt")

    # Carregar caixas Ground Truth
    if not os.path.exists(label_path):
        print(f"Label não encontrado para {image_name}. Pulando...")
        continue
    gt_boxes, gt_classes = load_ground_truth(label_path, image)

    pred_path = os.path.join("/kaggle/working/post_process", os.path.splitext(image_name)[0] + ".txt")
    if not os.path.exists(pred_path):
        print(f"Predição não encontrada para {image_name}. Pulando...")
        continue
    pred_boxes, pred_classes = load_ground_truth(pred_path, image)

    matches = match_predictions_with_gt(gt_boxes, pred_boxes)

    for gt_idx, pred_idx, iou in matches:
        if gt_idx is not None:
            gt_box = gt_boxes[gt_idx]
            gt_class = gt_classes[gt_idx]
        else:
            gt_box, gt_class = None, None  # Não foi detectado
    
        if pred_idx is not None:
            pred_box = pred_boxes[pred_idx]
            pred_class = pred_classes[pred_idx]
        else:
            pred_box, pred_class = None, None  # Previsão sem correspondência
    
        # Desenhar caixas na imagem
        if gt_box is not None and pred_box is not None:
            class_correct = gt_class == pred_class
            # Caso normal: GT e predição correspondem
            if class_correct:
                print(f"imagem:{image_name}; iou: {iou}; classe correta")
            else:
                print(f"imagem: {image_name}; IoU: {iou:.2f}; classe incorreta (GT: {gt_class}, Pred: {pred_class}).")
                
            image = draw_bounding_boxes(image, gt_box, pred_box, iou, class_correct=class_correct)
                
        elif gt_box is not None:
            # Caso: GT sem correspondência (IoU = 0)
            print(f"imagem:{image_name}; objeto não detectado. IoU: 0")
            image = draw_bounding_boxes(image, gt_box, [0, 0, 0, 0], 0)
       
        elif pred_box is not None:
            # Caso: Previsão sem correspondência
            print(f"imagem:{image_name}; falso positivo detectado. IoU: 0")
            image = draw_bounding_boxes(image, [0, 0, 0, 0], pred_box, 0, false_positive=True)

    save_path = os.path.join(output_dir, image_name)
    cv2.imwrite(save_path, image)
# Out:
# imagem:BNMN172.png; iou: 0.918918918918919; classe correta
# imagem:BNMN172.png; iou: 0.7161125319693095; classe correta
# imagem:BNMN172.png; iou: 0.8989416891471259; classe correta
# imagem:BN379.png; iou: 0.9687823030804218; classe correta
# imagem:BN53.png; iou: 0.965487642444872; classe correta
# imagem:BN561.png; iou: 0.9051878354203936; classe correta
# imagem:BN561.png; iou: 0.9253254406872888; classe correta
# imagem:BN682.png; iou: 0.929408444482619; classe correta
# imagem:BN584.png; iou: 0.972846149033348; classe correta
# imagem:BNMN301.png; iou: 0.846262341325811; classe correta
# imagem:BNMN301.png; iou: 0.9230111206159111; classe correta
# imagem:BNMN260.png; iou: 0.8126126126126126; classe correta
# imagem:BNMN260.png; iou: 0.9282956425813569; classe correta
# imagem:BNMN260.png; falso positivo detectado. IoU: 0
# imagem:BNMN147.png; iou: 0.7044025157232704; classe correta
# imagem:BNMN147.png; iou: 0.9291547427933273; classe correta
# imagem:BNMN147.png; iou: 0.6388888888888888; classe correta
# imagem:BNMN147.png; falso positivo detectado. IoU: 0
# imagem:BN557.png; iou: 0.9435637663885578; classe correta
# imagem:BNMN293.png; iou: 0.8625632377740303; classe correta
# imagem:BNMN293.png; iou: 0.9430327868852459; classe correta
# imagem:BNMN293.png; iou: 0.9661666341970258; classe correta
# imagem:BN201.png; iou: 0.9471501378126788; classe correta
# imagem:BN333.png; iou: 0.8679780106510909; classe correta
# imagem:BN272.png; iou: 0.9317925217506807; classe correta
# imagem:BN113.png; iou: 0.8781979562914896; classe correta
# imagem:BN261.png; iou: 0.834733824329; classe correta
# imagem: BN509.png; IoU: 0.90; classe incorreta (GT: 0, Pred: 1).
# imagem:BN509.png; falso positivo detectado. IoU: 0
# imagem:BNMN184.png; iou: 0.6918604651162791; classe correta
# imagem:BNMN184.png; iou: 0.8878863893833954; classe correta
# imagem:BNMN368.png; iou: 0.6222222222222222; classe correta
# imagem:BNMN368.png; iou: 0.9375087493350506; classe correta
# imagem:BNMN368.png; falso positivo detectado. IoU: 0
# imagem:BNMN253.png; iou: 0.7843137254901961; classe correta
# imagem:BNMN253.png; iou: 0.9409635828997964; classe correta
# imagem:BNMN168.png; iou: 0.6008531383302864; classe correta
# imagem:BNMN168.png; iou: 0.599128540305011; classe correta
# imagem:BNMN168.png; iou: 0.7163515016685206; classe correta
# imagem:BNMN168.png; iou: 0.9569150478399536; classe correta
# imagem: BN270.png; IoU: 0.89; classe incorreta (GT: 0, Pred: 1).
# imagem:BN270.png; falso positivo detectado. IoU: 0
# imagem:BN507.png; iou: 0.9663537906137184; classe correta
# imagem:BN470.png; iou: 0.9721787438548533; classe correta
# imagem: BN331.png; IoU: 0.87; classe incorreta (GT: 0, Pred: 1).
# imagem:BN331.png; falso positivo detectado. IoU: 0
# imagem:BNMN192.png; iou: 0.7488095238095238; classe correta
# imagem:BNMN192.png; iou: 0.8825086930168756; classe correta
# imagem:BNMN192.png; falso positivo detectado. IoU: 0
# imagem:BNMN192.png; falso positivo detectado. IoU: 0
# imagem: BN306.png; IoU: 0.92; classe incorreta (GT: 0, Pred: 1).
# imagem:BN306.png; falso positivo detectado. IoU: 0
# imagem:BN226.png; iou: 0.9403660231203619; classe correta
# imagem: BN226.png; IoU: 0.91; classe incorreta (GT: 0, Pred: 1).
# imagem:BN226.png; falso positivo detectado. IoU: 0
# imagem:BNMN360.png; iou: 0.9512195121951219; classe correta
# imagem:BNMN360.png; iou: 0.9368265897153771; classe correta
# imagem:BN274.png; iou: 0.9238096852382325; classe correta
# imagem:BN536.png; iou: 0.9275892175051839; classe correta
# imagem:BN536.png; falso positivo detectado. IoU: 0
# imagem:BNMN294.png; iou: 0.8210645526613817; classe correta
# imagem:BNMN294.png; iou: 0.9518813137474988; classe correta
# imagem: BNMN202.png; IoU: 0.04; classe incorreta (GT: 2, Pred: 0).
# imagem:BNMN202.png; iou: 0.926859250153657; classe correta
# imagem:BN205.png; iou: 0.9314707432788614; classe correta
# imagem:BN711.png; iou: 0.9776926638326529; classe correta
# imagem:BN302.png; iou: 0.8420275136183178; classe correta
# imagem:BN441.png; iou: 0.9548131491594389; classe correta
# imagem:BNMN208.png; iou: 0.7505154639175258; classe correta
# imagem:BNMN208.png; iou: 0.9696811017437293; classe correta
# imagem:BNMN208.png; falso positivo detectado. IoU: 0
# imagem:BN381.png; iou: 0.9349031534645101; classe correta
# imagem:BNMN336.png; iou: 0.7193077339102217; classe correta
# imagem:BNMN336.png; iou: 0.9422193040052528; classe correta
# imagem:BN556.png; iou: 0.9454614797864226; classe correta
# imagem:BN304.png; iou: 0.8972863507492912; classe correta
# imagem:BNMN206.png; iou: 0.7129446640316206; classe correta
# imagem:BNMN206.png; iou: 0.5941644562334217; classe correta
# imagem:BNMN206.png; iou: 0.9445752823422363; classe correta
# imagem: BNMN325.png; IoU: 0.93; classe incorreta (GT: 1, Pred: 0).
# imagem:BN725.png; iou: 0.9371915950459135; classe correta
# imagem:BNMN197.png; iou: 0.6721581548599671; classe correta
# imagem:BNMN197.png; iou: 0.9119753581087849; classe correta
# imagem:BN625.png; iou: 0.9529888068587758; classe correta

# %% [markdown]
# ### 8. Calcula as métricas das predições após o ensemble e o pós-processamento

# %%
def load_yolo_labels(txt_path):
    labels = []
    with open(txt_path, 'r') as f:
        for line in f.readlines():
            values = list(map(float, line.strip().split()))
            labels.append(values)  # Formato: [classe, x_c, y_c, w, h]
    return labels

def yolo_to_bbox(label, img_width=1, img_height=1):
    classe, x_c, y_c, w, h = label[:5]
    x_min = (x_c - w / 2) * img_width
    y_min = (y_c - h / 2) * img_height
    x_max = (x_c + w / 2) * img_width
    y_max = (y_c + h / 2) * img_height
    return [int(classe), x_min, y_min, x_max, y_max]

def calculate_iou(box1, box2):
    x1_min, y1_min, x1_max, y1_max = box1[1:]
    x2_min, y2_min, x2_max, y2_max = box2[1:]
    
    xi1 = max(x1_min, x2_min)
    yi1 = max(y1_min, y2_min)
    xi2 = min(x1_max, x2_max)
    yi2 = min(y1_max, y2_max)
    inter_area = max(0, xi2 - xi1) * max(0, yi2 - yi1)
    
    box1_area = (x1_max - x1_min) * (y1_max - y1_min)
    box2_area = (x2_max - x2_min) * (y2_max - y2_min)
    union_area = box1_area + box2_area - inter_area
    
    return inter_area / union_area if union_area > 0 else 0

def compute_ap(recalls, precisions):
    recalls = np.array(recalls)
    precisions = np.array(precisions)

    recalls = np.concatenate(([0.0], recalls, [1.0]))
    precisions = np.concatenate(([0.0], precisions, [0.0]))

    for i in range(len(precisions) - 1, 0, -1):
        precisions[i - 1] = max(precisions[i - 1], precisions[i])

    indices = np.where(np.diff(recalls) > 0)[0]

    ap = np.sum((recalls[indices + 1] - recalls[indices]) * precisions[indices + 1])

    return ap

def evaluate_detections(gt_dir, pred_dir, iou_thresholds=[0.5, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95]):
    gt_files = {f[:-4]: os.path.join(gt_dir, f) for f in os.listdir(gt_dir) if f.endswith('.txt')}
    pred_files = {f[:-4]: os.path.join(pred_dir, f) for f in os.listdir(pred_dir) if f.endswith('.txt')}
    
    TP, FP, FN = defaultdict(lambda: defaultdict(int)), defaultdict(lambda: defaultdict(int)), defaultdict(lambda: defaultdict(int))
    
    for file_id in gt_files.keys():
        gt_labels = [yolo_to_bbox(lbl) for lbl in load_yolo_labels(gt_files[file_id])]

        if file_id in pred_files:
            pred_labels = [yolo_to_bbox(lbl) for lbl in load_yolo_labels(pred_files[file_id])]

        else: 
            pred_labels = []
        
        for iou_threshold in iou_thresholds:
            matched = set()
            
            for pred in pred_labels:
                best_iou = 0
                best_match = None
                for idx, gt in enumerate(gt_labels):
                    if gt[0] == pred[0]:
                        iou = calculate_iou(pred, gt)
                        
                        if iou > best_iou:
                            best_iou = iou
                            best_match = idx
                
                if best_iou >= iou_threshold and best_match is not None and best_match not in matched:
                    TP[iou_threshold][pred[0]] += 1
                    matched.add(best_match)
                else:
                    FP[iou_threshold][pred[0]] += 1
            
            for idx, gt in enumerate(gt_labels):
                if idx not in matched:
                    FN[iou_threshold][gt[0]] += 1
    
    metrics = {}
    for iou_threshold in iou_thresholds:
        precisions, recalls, aps = {}, {}, {}
        for cls in [0, 1, 2]:
            precisions[cls] = TP[iou_threshold][cls] / (TP[iou_threshold][cls] + FP[iou_threshold][cls]) if (TP[iou_threshold][cls] + FP[iou_threshold][cls]) > 0 else 0
            recalls[cls] = TP[iou_threshold][cls] / (TP[iou_threshold][cls] + FN[iou_threshold][cls]) if (TP[iou_threshold][cls] + FN[iou_threshold][cls]) > 0 else 0
            # aps[cls] = precisions[cls] * recalls[cls]  # Aproximação do AP
        metrics[iou_threshold] = {"precisions": precisions, "recalls": recalls, "aps": aps}

    aps = {cls: compute_ap(
        [metrics[iou]['recalls'][cls] for iou in iou_thresholds], 
        [metrics[iou]['precisions'][cls] for iou in iou_thresholds])
        for cls in [0, 1, 2]} 
    
    for iou_threshold in iou_thresholds:
        metrics[iou_threshold]["aps"] = aps
    
    return metrics

gt_dir = '/kaggle/input/detectionbnmn-3classes/labels/test'
pred_dir = '/kaggle/input/predicts-ensemble/predict_ensemble/kaggle/working/final_predict_ensemble'
metrics = evaluate_detections(gt_dir, pred_dir, iou_thresholds=[0.5, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95])

print("Classe | Precisão | Recall | mAP50 | mAP50-95")
print("--------------------------------------------------")
for cls in [0, 1, 2]:
    prec50 = metrics[0.5]['precisions'][cls]
    rec50 = metrics[0.5]['recalls'][cls]
    ap50 = metrics[0.5]['aps'][cls]
    ap5095 = (metrics[0.5]['aps'][cls] + metrics[0.55]['aps'][cls] + metrics[0.60]['aps'][cls] + metrics[0.65]['aps'][cls] + metrics[0.70]['aps'][cls] + metrics[0.75]['aps'][cls] + metrics[0.80]['aps'][cls] + metrics[0.85]['aps'][cls] + metrics[0.90]['aps'][cls] + metrics[0.95]['aps'][cls]) / 10  # Aproximação para mAP50-95
    print(f"{cls:^6} | {prec50:.4f} | {rec50:.4f} | {ap50:.4f} | {ap5095:.4f}")
# Out:
# Classe | Precisão | Recall | mAP50 | mAP50-95
# --------------------------------------------------
#   0    | 0.8969 | 0.9886 | 0.8867 | 0.8867
#   1    | 0.9340 | 0.9429 | 0.8806 | 0.8806
#   2    | 0.7403 | 0.9116 | 0.6749 | 0.6749

# %% [markdown]
# ### 9. Compactação dos resultados das predições das imagens para download

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))


download_file('/kaggle/working/post_process', 'postprocess')
# Out:
# /kaggle/working/postprocess.zip
